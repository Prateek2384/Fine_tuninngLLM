# %%
import json
import random
from sklearn.model_selection import train_test_split

def transform_entry(original_entry):
    """Convert nested JSON to text-to-text format"""
    return {
        "input": original_entry["input"],
        "output": json.dumps(original_entry["analysis"])
    }


original_data = [
    {
        "input": "I'm Professor Williams. Please compile research papers on neural networks and remind me about the faculty meeting on Friday.",
        "analysis": {
            "instructions": [
                "compile research papers on neural networks",
                "remind about faculty meeting on Friday"
            ],
            "actions": [
                "gather academic papers",
                "set meeting reminder"
            ],
            "user_info": {
                "name": "Professor Williams",
                "designation": "professor"
            }
        }
    },
    {
      "input": "Hi, I'm John, a senior developer. Can you help me debug this code and set up a meeting with the team tomorrow?",
      "analysis": {
        "instructions": [
          "help debug this code",
          "set up a meeting with the team tomorrow"
        ],
        "actions": [
          "analyze and debug code",
          "schedule team meeting for tomorrow"
        ],
        "user_info": {
          "name": "John",
          "designation": "senior developer"
        }
      }
    },
    {
      "input": "This is Dr. Emily Carter. Please book my appointment with the cardiology department and remind me to take my medication at 8 PM.",
      "analysis": {
        "instructions": [
          "book appointment with cardiology department",
          "remind to take medication at 8 PM"
        ],
        "actions": [
          "schedule doctor's appointment",
          "set medication reminder"
        ],
        "user_info": {
          "name": "Dr. Emily Carter",
          "designation": "doctor"
        }
      }
    },
    {
    "input": "Hi, I'm Alex, a backend engineer. Can you help optimize this SQL query and review my pull request?",
    "analysis": {
      "instructions": ["optimize SQL query", "review pull request"],
      "actions": ["analyze and optimize SQL query", "review GitHub pull request"],
      "user_info": {"name": "Alex", "designation": "backend engineer"}
      }
    },
    {
    "input": "Hey, I'm Priya, a DevOps specialist. The CI/CD pipeline is failing—can you check the logs and alert the QA team?",
    "analysis": {
      "instructions": ["check CI/CD pipeline logs", "alert QA team"],
      "actions": ["diagnose pipeline failure", "notify QA team via Slack/email"],
      "user_info": {"name": "Priya", "designation": "DevOps specialist"}
        }
    },
    {
    "input": "I'm Mark, a junior developer. How do I resolve these merge conflicts in Git? Also, book a pairing session with my mentor.",
    "analysis": {
      "instructions": ["resolve Git merge conflicts", "book pairing session with mentor"],
      "actions": ["guide through conflict resolution", "schedule calendar meeting with mentor"],
      "user_info": {"name": "Mark", "designation": "junior developer"}
        }
    },
    {
    "input": "This is Elena, lead frontend architect. Draft a proposal for migrating our React components to TypeScript by EOD.",
    "analysis": {
      "instructions": ["draft TypeScript migration proposal"],
      "actions": ["create migration plan document", "share with team by EOD"],
      "user_info": {"name": "Elena", "designation": "lead frontend architect"}
        }
    },
    {
    "input": "I'm Carlos, an SRE. The production servers are overheating—generate a report and schedule an emergency meeting with engineering.",
    "analysis": {
      "instructions": ["generate server report", "schedule emergency meeting"],
      "actions": ["compile server health metrics", "create calendar invite for engineering team"],
      "user_info": {"name": "Carlos", "designation": "SRE"}
        }
    },
    {
    "input": "Hi, I'm Naomi, a data scientist. The ML model’s accuracy dropped—help me debug the training script and email the results to stakeholders.",
    "analysis": {
      "instructions": ["debug ML training script", "email results to stakeholders"],
      "actions": ["analyze model performance", "draft stakeholder update email"],
      "user_info": {"name": "Naomi", "designation": "data scientist"}
        }
    },
    {
    "input": "I'm Raj, a mobile dev. The app crashes on iOS 15. Pull the crash logs and assign a ticket to the QA team.",
    "analysis": {
      "instructions": ["pull iOS crash logs", "assign QA ticket"],
      "actions": ["extract logs from Firebase", "create Jira ticket for QA"],
      "user_info": {"name": "Raj", "designation": "mobile developer"}
    }
  },
  {
    "input": "This is Liam, security engineer. Scan the codebase for vulnerabilities and share a report with the CTO.",
    "analysis": {
      "instructions": ["scan codebase for vulnerabilities", "share report with CTO"],
      "actions": ["run security scan (e.g., Snyk/SonarQube)", "email PDF report to CTO"],
      "user_info": {"name": "Liam", "designation": "security engineer"}
    }
  },
  {
    "input": "Hey, I'm Zoe, a QA lead. The regression tests failed—notify the dev team and reschedule the test suite for tonight.",
    "analysis": {
      "instructions": ["notify dev team of failures", "reschedule regression tests"],
      "actions": ["post failure details in #dev channel", "update Jenkins/Nightwatch schedule"],
      "user_info": {"name": "Zoe", "designation": "QA lead"}
    }
  },
  {
    "input": "I'm Derek, a database admin. The read replicas are lagging—troubleshoot and update the incident log.",
    "analysis": {
      "instructions": ["troubleshoot replica lag", "update incident log"],
      "actions": ["check replication metrics in AWS RDS", "document findings in Confluence"],
      "user_info": {"name": "Derek", "designation": "database admin"}
    }
  },
    {
      "input": "I'm Mark, the operations manager. Need you to prepare a logistics report and email it to the stakeholders by EOD.",
      "analysis": {
        "instructions": [
          "prepare a logistics report",
          "email it to stakeholders by EOD"
        ],
        "actions": [
          "generate logistics report",
          "send email to stakeholders"
        ],
        "user_info": {
          "name": "Mark",
          "designation": "operations manager"
        }
      }
    },
    {
      "input": "Hey, I'm Lisa, a freelance writer. Can you research trending topics in tech and draft an outline for my next article?",
      "analysis": {
        "instructions": [
          "research trending topics in tech",
          "draft an outline for next article"
        ],
        "actions": [
          "find trending tech topics",
          "create article outline"
        ],
        "user_info": {
          "name": "Lisa",
          "designation": "freelance writer"
        }
      }
    },
    {
      "input": "This is Captain Raj from Flight 451. Requesting weather updates for our destination and clearance for an early landing.",
      "analysis": {
        "instructions": [
          "provide weather updates for destination",
          "request clearance for early landing"
        ],
        "actions": [
          "check destination weather",
          "contact ATC for landing clearance"
        ],
        "user_info": {
          "name": "Captain Raj",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Dr. Patel from City Hospital. Please schedule a follow-up appointment for Mr. Sharma and order lab tests for his blood work.",
      "analysis": {
        "instructions": [
          "schedule follow-up appointment for Mr. Sharma",
          "order lab tests for blood work"
        ],
        "actions": [
          "book doctor's appointment",
          "request lab tests"
        ],
        "user_info": {
          "name": "Dr. Patel",
          "designation": "doctor"
        }
      }
    },
    {
      "input": "This is Sarah, the marketing lead. Draft a campaign proposal for the new product launch and share it with the sales team.",
      "analysis": {
        "instructions": [
          "draft campaign proposal for product launch",
          "share it with sales team"
        ],
        "actions": [
          "create marketing proposal",
          "send document to sales team"
        ],
        "user_info": {
          "name": "Sarah",
          "designation": "marketing lead"
        }
      }
    },
    {
      "input": "I'm Professor Lee. Compile a list of references for my research paper on renewable energy and remind me about the conference next month.",
      "analysis": {
        "instructions": [
          "compile references for research paper",
          "remind about conference next month"
        ],
        "actions": [
          "gather academic sources",
          "set calendar reminder"
        ],
        "user_info": {
          "name": "Professor Lee",
          "designation": "professor"
        }
      }
    },
    {
      "input": "Hey, I'm Alex, a software engineer. Debug this Python script and find optimization techniques for faster execution.",
      "analysis": {
        "instructions": [
          "debug Python script",
          "find optimization techniques"
        ],
        "actions": [
          "analyze code errors",
          "research performance improvements"
        ],
        "user_info": {
          "name": "Alex",
          "designation": "software engineer"
        }
      }
    },
    {
      "input": "This is Chief Inspector Kumar. Requesting criminal records for suspect ID #4572 and alert the forensic team for analysis.",
      "analysis": {
        "instructions": [
          "fetch criminal records for suspect #4572",
          "alert forensic team"
        ],
        "actions": [
          "search police database",
          "notify forensic department"
        ],
        "user_info": {
          "name": "Chief Inspector Kumar",
          "designation": "police officer"
        }
      }
    },
    {
      "input": "I'm Emma, the HR manager. Schedule interviews for the shortlisted candidates and prepare onboarding documents.",
      "analysis": {
        "instructions": [
          "schedule candidate interviews",
          "prepare onboarding documents"
        ],
        "actions": [
          "coordinate interview slots",
          "generate HR paperwork"
        ],
        "user_info": {
          "name": "Emma",
          "designation": "HR manager"
        }
      }
    },
    {
      "input": "This is Captain Rodriguez. Need flight path clearance for Route Bravo and update the crew about turbulence warnings.",
      "analysis": {
        "instructions": [
          "get flight path clearance for Route Bravo",
          "update crew about turbulence"
        ],
        "actions": [
          "request ATC approval",
          "issue crew alert"
        ],
        "user_info": {
          "name": "Captain Rodriguez",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm David, a financial analyst. Pull stock market trends for Q2 and generate a risk assessment report.",
      "analysis": {
        "instructions": [
          "pull stock market trends for Q2",
          "generate risk assessment report"
        ],
        "actions": [
          "analyze market data",
          "create financial report"
        ],
        "user_info": {
          "name": "David",
          "designation": "financial analyst"
        }
      }
    },
    {
      "input": "This is Lieutenant Smith. Request backup at grid location E7 and scan for hostile activity in the perimeter.",
      "analysis": {
        "instructions": [
          "request backup at grid E7",
          "scan for hostile activity"
        ],
        "actions": [
          "call reinforcement units",
          "deploy surveillance"
        ],
        "user_info": {
          "name": "Lieutenant Smith",
          "designation": "military officer"
        }
      }
    },
    {
      "input": "I'm Sophia, the event planner. Finalize the guest list for the gala and confirm catering arrangements.",
      "analysis": {
        "instructions": [
          "finalize gala guest list",
          "confirm catering arrangements"
        ],
        "actions": [
          "update attendee list",
          "verify catering details"
        ],
        "user_info": {
          "name": "Sophia",
          "designation": "event planner"
        }
      }
    },
    {
      "input": "This is Engineer Gupta. Inspect the construction site for safety compliance and file a progress report.",
      "analysis": {
        "instructions": [
          "inspect construction site safety",
          "file progress report"
        ],
        "actions": [
          "conduct safety audit",
          "document project status"
        ],
        "user_info": {
          "name": "Engineer Gupta",
          "designation": "civil engineer"
        }
      }
    },
    {
      "input": "I'm Rachel, the editor. Proofread the manuscript for grammatical errors and format it for publishing.",
      "analysis": {
        "instructions": [
          "proofread manuscript",
          "format for publishing"
        ],
        "actions": [
          "check grammar/spelling",
          "adjust document layout"
        ],
        "user_info": {
          "name": "Rachel",
          "designation": "editor"
        }
      }
    },
    {
      "input": "This is Sergeant Diaz. Secure the crime scene and collect witness statements from the vicinity.",
      "analysis": {
        "instructions": [
          "secure crime scene",
          "collect witness statements"
        ],
        "actions": [
          "deploy security perimeter",
          "interview witnesses"
        ],
        "user_info": {
          "name": "Sergeant Diaz",
          "designation": "police officer"
        }
      }
    },
    {
      "input": "I'm Daniel, a data scientist. Clean the dataset for outliers and run a predictive model on the updated data.",
      "analysis": {
        "instructions": [
          "clean dataset for outliers",
          "run predictive model"
        ],
        "actions": [
          "filter anomalous data",
          "execute ML algorithm"
        ],
        "user_info": {
          "name": "Daniel",
          "designation": "data scientist"
        }
      }
    },
    {
      "input": "This is Captain Wu. Request refueling at the next checkpoint and check engine diagnostics for anomalies.",
      "analysis": {
        "instructions": [
          "request refueling at checkpoint",
          "check engine diagnostics"
        ],
        "actions": [
          "schedule fuel replenishment",
          "run system scan"
        ],
        "user_info": {
          "name": "Captain Wu",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Olivia, the sales director. Analyze last quarter’s revenue trends and prepare a pitch for potential investors.",
      "analysis": {
        "instructions": [
          "analyze revenue trends",
          "prepare investor pitch"
        ],
        "actions": [
          "generate sales report",
          "create presentation"
        ],
        "user_info": {
          "name": "Olivia",
          "designation": "sales director"
        }
      }
    },
    {
      "input": "This is Dr. Bennett. Prescribe 500mg antibiotics for Patient #3021 and notify the nursing staff for administration.",
      "analysis": {
        "instructions": [
          "prescribe antibiotics for Patient #3021",
          "notify nursing staff"
        ],
        "actions": [
          "issue medication order",
          "alert medical team"
        ],
        "user_info": {
          "name": "Dr. Bennett",
          "designation": "doctor"
        }
      }
    },
    {
      "input": "I'm Ryan, the IT admin. Reset passwords for the finance team and run a security audit on the servers.",
      "analysis": {
        "instructions": [
          "reset finance team passwords",
          "run server security audit"
        ],
        "actions": [
          "update login credentials",
          "scan for vulnerabilities"
        ],
        "user_info": {
          "name": "Ryan",
          "designation": "IT admin"
        }
      }
    },
    {
      "input": "This is Commander Ali. Deploy reconnaissance drones in Sector 4 and report any suspicious movements.",
      "analysis": {
        "instructions": [
          "deploy drones in Sector 4",
          "report suspicious activity"
        ],
        "actions": [
          "launch surveillance drones",
          "monitor live feed"
        ],
        "user_info": {
          "name": "Commander Ali",
          "designation": "military officer"
        }
      }
    },
    {
      "input": "I'm Nina, the logistics coordinator. Track shipment #7890 and reroute it to the warehouse in Dallas.",
      "analysis": {
        "instructions": [
          "track shipment #7890",
          "reroute to Dallas warehouse"
        ],
        "actions": [
          "monitor delivery status",
          "update destination"
        ],
        "user_info": {
          "name": "Nina",
          "designation": "logistics coordinator"
        }
      }
    },
    {
      "input": "This is Detective Morgan. Run a background check on suspect ID #8892 and cross-reference with recent crime reports.",
      "analysis": {
        "instructions": [
          "run background check on suspect #8892",
          "cross-reference with crime reports"
        ],
        "actions": [
          "access police database",
          "compare with recent cases"
        ],
        "user_info": {
          "name": "Detective Morgan",
          "designation": "detective"
        }
      }
    },
    {
      "input": "I'm Dr. Chen from Mercy Hospital. Order an MRI scan for patient #4415 and notify the radiologist for priority review.",
      "analysis": {
        "instructions": [
          "order MRI scan for patient #4415",
          "notify radiologist for priority"
        ],
        "actions": [
          "schedule medical imaging",
          "alert radiology department"
        ],
        "user_info": {
          "name": "Dr. Chen",
          "designation": "doctor"
        }
      }
    },
    {
      "input": "This is Captain Alvarez. Request permission for altitude change to 35,000 feet and check weather patterns along the new route.",
      "analysis": {
        "instructions": [
          "request altitude change to 35,000 feet",
          "check weather on new route"
        ],
        "actions": [
          "contact air traffic control",
          "analyze meteorological data"
        ],
        "user_info": {
          "name": "Captain Alvarez",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm James, the cybersecurity specialist. Scan the network for vulnerabilities and update firewall protocols immediately.",
      "analysis": {
        "instructions": [
          "scan network for vulnerabilities",
          "update firewall protocols"
        ],
        "actions": [
          "run security diagnostics",
          "implement firewall upgrades"
        ],
        "user_info": {
          "name": "James",
          "designation": "cybersecurity specialist"
        }
      }
    },
    {
      "input": "This is Sergeant Park. Secure perimeter around the embassy and coordinate with local law enforcement for backup.",
      "analysis": {
        "instructions": [
          "secure embassy perimeter",
          "coordinate with local police"
        ],
        "actions": [
          "deploy security forces",
          "establish communication channel"
        ],
        "user_info": {
          "name": "Sergeant Park",
          "designation": "military police"
        }
      }
    },
    {
      "input": "I'm Lisa, the UX designer. Create wireframes for the new mobile app and gather feedback from focus groups.",
      "analysis": {
        "instructions": [
          "create mobile app wireframes",
          "gather focus group feedback"
        ],
        "actions": [
          "design prototype screens",
          "organize user testing"
        ],
        "user_info": {
          "name": "Lisa",
          "designation": "UX designer"
        }
      }
    },
    {
      "input": "This is Inspector Gadhavi. Freeze all assets linked to account #XJ-8876 and alert the financial crimes unit.",
      "analysis": {
        "instructions": [
          "freeze assets for account #XJ-8876",
          "alert financial crimes unit"
        ],
        "actions": [
          "block financial transactions",
          "notify investigation team"
        ],
        "user_info": {
          "name": "Inspector Gadhavi",
          "designation": "financial investigator"
        }
      }
    },
    {
      "input": "I'm Dr. Reynolds. Prepare the OR for emergency appendectomy and page the anesthesiology team stat.",
      "analysis": {
        "instructions": [
          "prepare OR for appendectomy",
          "page anesthesiology team"
        ],
        "actions": [
          "set up surgical theater",
          "emergency contact medical staff"
        ],
        "user_info": {
          "name": "Dr. Reynolds",
          "designation": "surgeon"
        }
      }
    },
    {
      "input": "This is Commander Briggs. Initiate evacuation protocol for Sector Delta and deploy rescue helicopters.",
      "analysis": {
        "instructions": [
          "initiate Sector Delta evacuation",
          "deploy rescue helicopters"
        ],
        "actions": [
          "activate emergency procedures",
          "mobilize air rescue units"
        ],
        "user_info": {
          "name": "Commander Briggs",
          "designation": "emergency response"
        }
      }
    },
    {
      "input": "I'm Priya, the AI researcher. Benchmark our neural network against GPT-4 and compile performance metrics.",
      "analysis": {
        "instructions": [
          "benchmark neural network vs GPT-4",
          "compile performance metrics"
        ],
        "actions": [
          "run comparative tests",
          "generate analysis report"
        ],
        "user_info": {
          "name": "Priya",
          "designation": "AI researcher"
        }
      }
    },
    {
      "input": "This is Captain Zhou. Request ground crew assistance at Gate B7 and update passenger manifest with last-minute changes.",
      "analysis": {
        "instructions": [
          "request ground crew at Gate B7",
          "update passenger manifest"
        ],
        "actions": [
          "call airport staff",
          "modify flight records"
        ],
        "user_info": {
          "name": "Captain Zhou",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Mark, the robotics engineer. Calibrate the industrial robot arms in Bay 3 and run diagnostic tests.",
      "analysis": {
        "instructions": [
          "calibrate robot arms in Bay 3",
          "run diagnostic tests"
        ],
        "actions": [
          "adjust machine precision",
          "execute system checks"
        ],
        "user_info": {
          "name": "Mark",
          "designation": "robotics engineer"
        }
      }
    },
    {
      "input": "This is Lieutenant Cruz. Establish communication with HQ via secure channel and encrypt all field reports.",
      "analysis": {
        "instructions": [
          "establish secure comms with HQ",
          "encrypt field reports"
        ],
        "actions": [
          "activate encrypted line",
          "apply cryptographic protocols"
        ],
        "user_info": {
          "name": "Lieutenant Cruz",
          "designation": "military intelligence"
        }
      }
    },
    {
      "input": "I'm Dr. Kapoor. Adjust medication dosage for patient in Room 304 and schedule physiotherapy sessions.",
      "analysis": {
        "instructions": [
          "adjust medication for Room 304",
          "schedule physiotherapy"
        ],
        "actions": [
          "modify prescription",
          "book rehabilitation slots"
        ],
        "user_info": {
          "name": "Dr. Kapoor",
          "designation": "physician"
        }
      }
    },
    {
      "input": "This is Captain Silva. Request priority landing clearance due to medical emergency onboard. Prepare medical team on arrival.",
      "analysis": {
        "instructions": [
          "request priority landing clearance",
          "prepare medical team"
        ],
        "actions": [
          "declare emergency to ATC",
          "alert airport medical staff"
        ],
        "user_info": {
          "name": "Captain Silva",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Elena, the architect. Revise blueprints for client approval and calculate material requirements for Phase 1.",
      "analysis": {
        "instructions": [
          "revise client blueprints",
          "calculate Phase 1 materials"
        ],
        "actions": [
          "modify design documents",
          "estimate construction supplies"
        ],
        "user_info": {
          "name": "Elena",
          "designation": "architect"
        }
      }
    },
    {
      "input": "This is Inspector Murthy. Execute search warrant at 45 Maple Street and preserve all digital evidence.",
      "analysis": {
        "instructions": [
          "execute search warrant",
          "preserve digital evidence"
        ],
        "actions": [
          "conduct property search",
          "secure electronic devices"
        ],
        "user_info": {
          "name": "Inspector Murthy",
          "designation": "police detective"
        }
      }
    },
    {
      "input": "I'm Dr. Wagner. Analyze biopsy results from Lab #887 and prepare consultation notes for the oncology team.",
      "analysis": {
        "instructions": [
          "analyze biopsy results",
          "prepare oncology notes"
        ],
        "actions": [
          "interpret lab data",
          "compile medical documentation"
        ],
        "user_info": {
          "name": "Dr. Wagner",
          "designation": "pathologist"
        }
      }
    },
    {
      "input": "This is Commander Lee. Deploy reconnaissance team to Grid F12 and establish surveillance points.",
      "analysis": {
        "instructions": [
          "deploy recon team to F12",
          "establish surveillance"
        ],
        "actions": [
          "send field operatives",
          "set up observation posts"
        ],
        "user_info": {
          "name": "Commander Lee",
          "designation": "special forces"
        }
      }
    },
    {
      "input": "I'm Carlos, the quantum physicist. Simulate quantum entanglement experiments and verify results against theoretical models.",
      "analysis": {
        "instructions": [
          "simulate quantum experiments",
          "verify theoretical models"
        ],
        "actions": [
          "run computational models",
          "compare with predictions"
        ],
        "user_info": {
          "name": "Carlos",
          "designation": "quantum physicist"
        }
      }
    },
    {
      "input": "This is Captain Dubois. Request refueling at alternate airport due to closure and update flight plan accordingly.",
      "analysis": {
        "instructions": [
          "request refueling at alternate airport",
          "update flight plan"
        ],
        "actions": [
          "locate backup fuel station",
          "file revised route"
        ],
        "user_info": {
          "name": "Captain Dubois",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Dr. Tanaka. Review patient #3321's allergy history before prescribing antibiotics and flag for pharmacist verification.",
      "analysis": {
        "instructions": [
          "review patient #3321's allergies",
          "flag for pharmacist"
        ],
        "actions": [
          "check medical records",
          "add prescription alert"
        ],
        "user_info": {
          "name": "Dr. Tanaka",
          "designation": "pediatrician"
        }
      }
    },
    {
      "input": "This is Major Khan. Coordinate airdrop of supplies to coordinates 34.5N 72.1E and confirm delivery with ground team.",
      "analysis": {
        "instructions": [
          "coordinate supply airdrop",
          "confirm delivery"
        ],
        "actions": [
          "calculate drop trajectory",
          "establish radio confirmation"
        ],
        "user_info": {
          "name": "Major Khan",
          "designation": "military logistics"
        }
      }
    },
    {
      "input": "I'm Naomi, the marine biologist. Tag and release the shark specimen after taking tissue samples for genomic analysis.",
      "analysis": {
        "instructions": [
          "tag and release shark",
          "collect tissue samples"
        ],
        "actions": [
          "attach tracking device",
          "preserve biological samples"
        ],
        "user_info": {
          "name": "Naomi",
          "designation": "marine biologist"
        }
      }
    },
    {
      "input": "This is Captain Petrov. Initiate de-icing procedures on Runway 3 and delay departures until weather clears.",
      "analysis": {
        "instructions": [
          "initiate runway de-icing",
          "delay departures"
        ],
        "actions": [
          "dispatch de-icing trucks",
          "update flight schedules"
        ],
        "user_info": {
          "name": "Captain Petrov",
          "designation": "air traffic control"
        }
      }
    },
    {
      "input": "I'm Dr. Bennett. Prepare quarantine protocol for suspected viral outbreak in Ward 5 and notify CDC liaison.",
      "analysis": {
        "instructions": [
          "prepare quarantine for Ward 5",
          "notify CDC"
        ],
        "actions": [
          "isolate affected area",
          "contact health authorities"
        ],
        "user_info": {
          "name": "Dr. Bennett",
          "designation": "epidemiologist"
        }
      }
    },
    {
      "input": "This is Colonel Zhang. Activate missile defense system in Sector 9 and scramble interceptors to patrol zone.",
      "analysis": {
        "instructions": [
          "activate missile defense",
          "scramble interceptors"
        ],
        "actions": [
          "enable defense grid",
          "dispatch fighter jets"
        ],
        "user_info": {
          "name": "Colonel Zhang",
          "designation": "air defense"
        }
      }
    },
    {
      "input": "I'm Dr. Romano. Cross-match blood types for transplant patient #4456 and prepare OR for potential emergency surgery.",
      "analysis": {
        "instructions": [
          "cross-match blood types",
          "prepare OR for surgery"
        ],
        "actions": [
          "conduct blood compatibility tests",
          "prep surgical team"
        ],
        "user_info": {
          "name": "Dr. Romano",
          "designation": "transplant surgeon"
        }
      }
    },
    {
      "input": "This is Captain Ngo. Request diplomatic clearance for emergency landing in foreign territory and contact embassy officials.",
      "analysis": {
        "instructions": [
          "request diplomatic clearance",
          "contact embassy"
        ],
        "actions": [
          "file international flight request",
          "reach diplomatic channels"
        ],
        "user_info": {
          "name": "Captain Ngo",
          "designation": "air force pilot"
        }
      }
    },
    {
      "input": "I'm Dr. Schmidt. Analyze seismic data from Station Alpha and predict potential aftershock epicenters.",
      "analysis": {
        "instructions": [
          "analyze seismic data",
          "predict aftershocks"
        ],
        "actions": [
          "process geological readings",
          "model tremor probabilities"
        ],
        "user_info": {
          "name": "Dr. Schmidt",
          "designation": "seismologist"
        }
      }
    },
    {
      "input": "This is Officer Reynolds. Secure the perimeter of 25th and Main after the bank robbery and collect all surveillance footage within 1 mile radius.",
      "analysis": {
        "instructions": [
          "secure crime scene perimeter",
          "collect nearby surveillance footage"
        ],
        "actions": [
          "establish police cordon",
          "request CCTV recordings"
        ],
        "user_info": {
          "name": "Officer Reynolds",
          "designation": "police officer"
        }
      }
    },
    {
      "input": "I'm Dr. Yamamoto. Prepare the ICU for incoming trauma patient with severe burns and alert the plastic surgery team.",
      "analysis": {
        "instructions": [
          "prepare ICU for burn patient",
          "alert plastic surgery team"
        ],
        "actions": [
          "set up critical care unit",
          "page specialist surgeons"
        ],
        "user_info": {
          "name": "Dr. Yamamoto",
          "designation": "trauma surgeon"
        }
      }
    },
    {
      "input": "This is Captain Okafor. Request diversion to Lagos International due to engine trouble and notify ground services of our emergency status.",
      "analysis": {
        "instructions": [
          "request diversion to Lagos",
          "notify ground services"
        ],
        "actions": [
          "declare emergency to ATC",
          "alert airport emergency teams"
        ],
        "user_info": {
          "name": "Captain Okafor",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Engineer Kowalski. Shut down Reactor #3 for emergency maintenance and initiate backup power systems.",
      "analysis": {
        "instructions": [
          "shut down Reactor #3",
          "activate backup power"
        ],
        "actions": [
          "begin safe shutdown sequence",
          "switch to auxiliary generators"
        ],
        "user_info": {
          "name": "Engineer Kowalski",
          "designation": "nuclear engineer"
        }
      }
    },
    {
      "input": "This is Director Chen. Redraft the quarterly financial report with updated projections and schedule an emergency board meeting for 3 PM today.",
      "analysis": {
        "instructions": [
          "redraft financial report",
          "schedule board meeting"
        ],
        "actions": [
          "update financial documents",
          "coordinate executive availability"
        ],
        "user_info": {
          "name": "Director Chen",
          "designation": "finance director"
        }
      }
    },
    {
      "input": "I'm Detective Alvarez. Run facial recognition on the suspect caught on camera at the jewelry store and check for prior arrests.",
      "analysis": {
        "instructions": [
          "run facial recognition",
          "check criminal records"
        ],
        "actions": [
          "process surveillance image",
          "search police database"
        ],
        "user_info": {
          "name": "Detective Alvarez",
          "designation": "detective"
        }
      }
    },
    {
      "input": "This is Commander Ibrahim. Deploy rapid response team to the embassy compound and establish communication with local authorities.",
      "analysis": {
        "instructions": [
          "deploy response team",
          "establish local comms"
        ],
        "actions": [
          "mobilize security personnel",
          "contact police headquarters"
        ],
        "user_info": {
          "name": "Commander Ibrahim",
          "designation": "security commander"
        }
      }
    },
    {
      "input": "I'm Dr. Petrov. Administer 2mg of Lorazepam to patient in Room 412 and monitor vitals every 15 minutes.",
      "analysis": {
        "instructions": [
          "administer medication",
          "monitor patient vitals"
        ],
        "actions": [
          "prepare and give dosage",
          "set up vital checks"
        ],
        "user_info": {
          "name": "Dr. Petrov",
          "designation": "psychiatrist"
        }
      }
    },
    {
      "input": "This is Captain De Silva. Request priority taxi clearance after landing and coordinate with customs for diplomatic baggage.",
      "analysis": {
        "instructions": [
          "request taxi clearance",
          "coordinate customs"
        ],
        "actions": [
          "contact ground control",
          "notify border officials"
        ],
        "user_info": {
          "name": "Captain De Silva",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Professor Zhang. Compile all research data on nanotechnology applications and prepare presentation slides for the conference.",
      "analysis": {
        "instructions": [
          "compile research data",
          "prepare presentation"
        ],
        "actions": [
          "organize study findings",
          "create visual materials"
        ],
        "user_info": {
          "name": "Professor Zhang",
          "designation": "nanotechnology researcher"
        }
      }
    },
    {
      "input": "This is Sergeant O'Reilly. Establish checkpoint at highway exit 42 and inspect all commercial vehicles for contraband.",
      "analysis": {
        "instructions": [
          "set up highway checkpoint",
          "inspect commercial vehicles"
        ],
        "actions": [
          "deploy inspection team",
          "search cargo trucks"
        ],
        "user_info": {
          "name": "Sergeant O'Reilly",
          "designation": "border patrol"
        }
      }
    },
    {
      "input": "I'm Dr. Kapoor. Order full blood work for patient in ER Bay 3 and consult with hematology specialist immediately.",
      "analysis": {
        "instructions": [
          "order blood tests",
          "consult hematology"
        ],
        "actions": [
          "request lab analysis",
          "page specialist doctor"
        ],
        "user_info": {
          "name": "Dr. Kapoor",
          "designation": "emergency physician"
        }
      }
    },
    {
      "input": "This is Engineer Tanaka. Initiate safety protocols for the offshore oil rig and evacuate non-essential personnel.",
      "analysis": {
        "instructions": [
          "initiate safety protocols",
          "evacuate personnel"
        ],
        "actions": [
          "activate emergency systems",
          "coordinate helicopter evacuation"
        ],
        "user_info": {
          "name": "Engineer Tanaka",
          "designation": "offshore engineer"
        }
      }
    },
    {
      "input": "I'm Director Müller. Freeze all transactions on account #7743-21 and alert the cybersecurity team about potential breach.",
      "analysis": {
        "instructions": [
          "freeze account transactions",
          "alert cybersecurity"
        ],
        "actions": [
          "block financial activity",
          "notify IT security"
        ],
        "user_info": {
          "name": "Director Müller",
          "designation": "bank manager"
        }
      }
    },
    {
      "input": "This is Captain Jansen. Request weather update for transatlantic crossing and adjust course to avoid storm system.",
      "analysis": {
        "instructions": [
          "get weather update",
          "adjust navigation course"
        ],
        "actions": [
          "contact meteorology service",
          "recalculate route"
        ],
        "user_info": {
          "name": "Captain Jansen",
          "designation": "ship captain"
        }
      }
    },
    {
      "input": "I'm Dr. Kim. Prepare operating theater for emergency C-section and notify pediatric team for immediate neonatal care.",
      "analysis": {
        "instructions": [
          "prepare OR for surgery",
          "alert pediatric team"
        ],
        "actions": [
          "set up surgical equipment",
          "page NICU staff"
        ],
        "user_info": {
          "name": "Dr. Kim",
          "designation": "obstetrician"
        }
      }
    },
    {
      "input": "This is Inspector Hassan. Secure evidence from the digital crime scene and create forensic copies of all hard drives.",
      "analysis": {
        "instructions": [
          "secure digital evidence",
          "create forensic copies"
        ],
        "actions": [
          "document electronic evidence",
          "make bit-by-bit copies"
        ],
        "user_info": {
          "name": "Inspector Hassan",
          "designation": "cybercrime investigator"
        }
      }
    },
    {
      "input": "I'm Professor Schmidt. Analyze the newly discovered virus sample and compare its genome with known pathogens.",
      "analysis": {
        "instructions": [
          "analyze virus sample",
          "compare genomes"
        ],
        "actions": [
          "conduct lab tests",
          "run bioinformatics analysis"
        ],
        "user_info": {
          "name": "Professor Schmidt",
          "designation": "virologist"
        }
      }
    },
    {
      "input": "This is Commander Yakubu. Mobilize peacekeeping forces to the conflict zone and establish humanitarian corridors.",
      "analysis": {
        "instructions": [
          "deploy peacekeepers",
          "create safe corridors"
        ],
        "actions": [
          "send UN troops",
          "negotiate safe passage"
        ],
        "user_info": {
          "name": "Commander Yakubu",
          "designation": "UN peacekeeper"
        }
      }
    },
    {
      "input": "I'm Dr. Wagner. Initiate lockdown of the biological research facility and quarantine all staff present during the breach.",
      "analysis": {
        "instructions": [
          "lockdown facility",
          "quarantine exposed staff"
        ],
        "actions": [
          "activate containment protocols",
          "isolate personnel"
        ],
        "user_info": {
          "name": "Dr. Wagner",
          "designation": "biosafety officer"
        }
      }
    },
    {
      "input": "This is Captain Moreno. Request air traffic control clearance for emergency landing at nearest suitable airport and prepare cabin for impact.",
      "analysis": {
        "instructions": [
          "request emergency landing",
          "prepare cabin"
        ],
        "actions": [
          "declare mayday to ATC",
          "brief crew for crash procedures"
        ],
        "user_info": {
          "name": "Captain Moreno",
          "designation": "airline pilot"
        }
      }
    },
    {
      "input": "I'm Engineer Park. Shut down the malfunctioning assembly line in Plant B and initiate diagnostic checks on all robotic units.",
      "analysis": {
        "instructions": [
          "stop assembly line",
          "run diagnostics"
        ],
        "actions": [
          "emergency power cutoff",
          "test robotic systems"
        ],
        "user_info": {
          "name": "Engineer Park",
          "designation": "industrial engineer"
        }
      }
    },
    {
      "input": "This is Director Johnson. Recall batch #XK-887 of the medication nationwide and issue public safety announcement immediately.",
      "analysis": {
        "instructions": [
          "recall medication batch",
          "issue public warning"
        ],
        "actions": [
          "notify pharmacies nationwide",
          "prepare press release"
        ],
        "user_info": {
          "name": "Director Johnson",
          "designation": "FDA official"
        }
      }
    },
    {
      "input": "I'm Detective Mwangi. Execute search warrant at the suspect's residence and preserve all electronic devices as evidence.",
      "analysis": {
        "instructions": [
          "execute search warrant",
          "secure digital evidence"
        ],
        "actions": [
          "conduct property search",
          "bag and tag electronics"
        ],
        "user_info": {
          "name": "Detective Mwangi",
          "designation": "police detective"
        }
      }
    },
    {
      "input": "This is Dr. Santos. Prepare ECMO machine for incoming COVID patient with severe ARDS and notify respiratory therapy team.",
      "analysis": {
        "instructions": [
          "prepare ECMO machine",
          "alert respiratory team"
        ],
        "actions": [
          "set up life support",
          "page specialists"
        ],
        "user_info": {
          "name": "Dr. Santos",
          "designation": "intensivist"
        }
      }
    },
    {
      "input": "I'm Captain Vogel. Request additional fuel trucks at the holding point and recalculate maximum payload for current conditions.",
      "analysis": {
        "instructions": [
          "request fuel trucks",
          "recalculate payload"
        ],
        "actions": [
          "coordinate refueling",
          "adjust weight calculations"
        ],
        "user_info": {
          "name": "Captain Vogel",
          "designation": "cargo pilot"
        }
      }
    },
    {
      "input": "This is Professor Chen. Replicate the quantum computing experiment with revised parameters and document any entanglement anomalies.",
      "analysis": {
        "instructions": [
          "replicate experiment",
          "record anomalies"
        ],
        "actions": [
          "adjust lab settings",
          "document quantum states"
        ],
        "user_info": {
          "name": "Professor Chen",
          "designation": "quantum physicist"
        }
      }
    },
    {
      "input": "I'm Commander Rossi. Deploy underwater drones to search the wreckage and map the debris field with sonar imaging.",
      "analysis": {
        "instructions": [
          "deploy search drones",
          "map debris field"
        ],
        "actions": [
          "launch ROVs",
          "conduct sonar scans"
        ],
        "user_info": {
          "name": "Commander Rossi",
          "designation": "naval officer"
        }
      }
    },
    {
      "input": "This is Dr. Andersen. Administer experimental treatment to patient in Trial Group B and monitor for adverse reactions every hour.",
      "analysis": {
        "instructions": [
          "give experimental treatment",
          "monitor reactions"
        ],
        "actions": [
          "prepare and administer drug",
          "schedule frequent checks"
        ],
        "user_info": {
          "name": "Dr. Andersen",
          "designation": "clinical researcher"
        }
      }
    },
    {
      "input": "I'm Inspector Zhao. Secure the financial crime scene and image all computers before the suspects can destroy evidence.",
      "analysis": {
        "instructions": [
          "secure crime scene",
          "preserve digital evidence"
        ],
        "actions": [
          "establish perimeter",
          "create forensic copies"
        ],
        "user_info": {
          "name": "Inspector Zhao",
          "designation": "financial crimes investigator"
        }
      }
    },
    {
      "input": "This is Engineer Dubois. Initiate emergency shutdown of the hydroelectric dam and divert water flow to secondary channels.",
      "analysis": {
        "instructions": [
          "shutdown dam",
          "divert water"
        ],
        "actions": [
          "activate emergency protocols",
          "control water gates"
        ],
        "user_info": {
          "name": "Engineer Dubois",
          "designation": "civil engineer"
        }
      }
    },
    {
      "input": "I'm Chef Martinez. Adjust the recipe for gluten-free diners and prep the station for tonight's 75-cover service.",
      "analysis": {
        "instructions": [
          "modify recipe for gluten-free",
          "prepare kitchen station"
        ],
        "actions": [
          "revise ingredient list",
          "organize cooking equipment"
        ],
        "user_info": {
          "name": "Chef Martinez",
          "designation": "head chef"
        }
      }
    },
    {
      "input": "This is Judge Wilkins. Schedule a recess until 2 PM and have the court reporter highlight all witness inconsistencies.",
      "analysis": {
        "instructions": [
          "schedule court recess",
          "analyze testimony records"
        ],
        "actions": [
          "announce break period",
          "flag contradictory statements"
        ],
        "user_info": {
          "name": "Judge Wilkins",
          "designation": "circuit judge"
        }
      }
    },
    {
      "input": "I'm Astronaut Chen. Run diagnostics on the life support systems and document any pressure fluctuations in Module 3.",
      "analysis": {
        "instructions": [
          "diagnose life support",
          "record pressure data"
        ],
        "actions": [
          "initiate system checks",
          "log environmental metrics"
        ],
        "user_info": {
          "name": "Astronaut Chen",
          "designation": "ISS crew member"
        }
      }
    },
    {
      "input": "This is Zookeeper Patel. Prepare the enrichment activities for the primate exhibit and monitor the new gorilla's socialization progress.",
      "analysis": {
        "instructions": [
          "create animal enrichment",
          "observe gorilla behavior"
        ],
        "actions": [
          "set up puzzle feeders",
          "document interaction logs"
        ],
        "user_info": {
          "name": "Zookeeper Patel",
          "designation": "primate specialist"
        }
      }
    },
    {
      "input": "I'm DJ Khaled. Cue up the next track and adjust the bass levels for the outdoor speaker system.",
      "analysis": {
        "instructions": [
          "prepare next song",
          "modify audio settings"
        ],
        "actions": [
          "load playlist item",
          "equalize sound system"
        ],
        "user_info": {
          "name": "DJ Khaled",
          "designation": "music producer"
        }
      }
    },
    {
      "input": "This is Archaeologist Dubois. Catalog the newly uncovered artifacts from Grid D7 and cross-reference with Bronze Age findings.",
      "analysis": {
        "instructions": [
          "document artifacts",
          "compare historical data"
        ],
        "actions": [
          "photograph and label items",
          "research archaeological records"
        ],
        "user_info": {
          "name": "Archaeologist Dubois",
          "designation": "field archaeologist"
        }
      }
    },
    {
      "input": "I'm Sommelier Ricci. Recommend three Italian reds for the tasting menu and decant the 1997 Barolo for table 12.",
      "analysis": {
        "instructions": [
          "suggest wine pairings",
          "prepare vintage wine"
        ],
        "actions": [
          "select appropriate bottles",
          "aerate specified wine"
        ],
        "user_info": {
          "name": "Sommelier Ricci",
          "designation": "wine expert"
        }
      }
    },
    {
      "input": "This is Electrician Okafor. Check the circuit breakers in Panel B and replace the faulty wiring in the east wing.",
      "analysis": {
        "instructions": [
          "inspect electrical panel",
          "repair damaged wires"
        ],
        "actions": [
          "test breaker switches",
          "install new cabling"
        ],
        "user_info": {
          "name": "Electrician Okafor",
          "designation": "master electrician"
        }
      }
    },
    {
      "input": "I'm Fashion Designer Laurent. Finalize the tech packs for the spring collection and schedule fittings with the models.",
      "analysis": {
        "instructions": [
          "complete design specs",
          "arrange model appointments"
        ],
        "actions": [
          "finalize garment details",
          "coordinate fitting times"
        ],
        "user_info": {
          "name": "Designer Laurent",
          "designation": "creative director"
        }
      }
    },
    {
      "input": "This is Park Ranger Kim. Track the GPS collars of the reintroduced wolf pack and document any territory overlaps.",
      "analysis": {
        "instructions": [
          "monitor animal movements",
          "record habitat usage"
        ],
        "actions": [
          "check telemetry data",
          "map range boundaries"
        ],
        "user_info": {
          "name": "Ranger Kim",
          "designation": "wildlife specialist"
        }
      }
    },
    {
      "input": "I'm Voice Actor Reynolds. Practice the commercial script with three different accents and record test takes for client approval.",
      "analysis": {
        "instructions": [
          "rehearse varied deliveries",
          "create audio samples"
        ],
        "actions": [
          "perform script variations",
          "produce demo recordings"
        ],
        "user_info": {
          "name": "Actor Reynolds",
          "designation": "voice artist"
        }
      }
    },
    {
      "input": "This is Glassblower Vitale. Adjust the furnace to 2100°F and prepare the colored rods for the commissioned sculpture.",
      "analysis": {
        "instructions": [
          "regulate kiln temperature",
          "organize materials"
        ],
        "actions": [
          "calibrate heating controls",
          "sort glass canes"
        ],
        "user_info": {
          "name": "Glassblower Vitale",
          "designation": "artisan"
        }
      }
    },
    {
      "input": "I'm Sports Analyst Torres. Compile the quarterback stats from Sunday's games and highlight third-down conversion patterns.",
      "analysis": {
        "instructions": [
          "gather player statistics",
          "analyze situational data"
        ],
        "actions": [
          "aggregate performance metrics",
          "identify trend correlations"
        ],
        "user_info": {
          "name": "Analyst Torres",
          "designation": "NFL commentator"
        }
      }
    },
    {
      "input": "This is Luthier Moreau. Inspect the violin's soundpost alignment and adjust the bridge height for optimal projection.",
      "analysis": {
        "instructions": [
          "examine interior structure",
          "modify component position"
        ],
        "actions": [
          "check post placement",
          "file bridge feet"
        ],
        "user_info": {
          "name": "Luthier Moreau",
          "designation": "instrument maker"
        }
      }
    },
    {
      "input": "I'm Stunt Coordinator Lee. Rehearse the car flip sequence with the new safety rig and confirm pyrotechnic timings.",
      "analysis": {
        "instructions": [
          "practice stunt maneuver",
          "verify special effects"
        ],
        "actions": [
          "run controlled flip",
          "sync explosion cues"
        ],
        "user_info": {
          "name": "Coordinator Lee",
          "designation": "stunt director"
        }
      }
    },
    {
      "input": "This is Horticulturist Park. Propagate the rare orchid cuttings and adjust the greenhouse humidity to 80%.",
      "analysis": {
        "instructions": [
          "cultivate plant divisions",
          "modify climate settings"
        ],
        "actions": [
          "prepare growth medium",
          "regulate misting system"
        ],
        "user_info": {
          "name": "Horticulturist Park",
          "designation": "botanist"
        }
      }
    },
    {
      "input": "I'm Auctioneer Delacroix. Research provenance for Lot 42 and prepare condition reports for the Ming vase.",
      "analysis": {
        "instructions": [
          "verify artwork history",
          "document artifact state"
        ],
        "actions": [
          "trace ownership records",
          "photograph imperfections"
        ],
        "user_info": {
          "name": "Auctioneer Delacroix",
          "designation": "art specialist"
        }
      }
    },
    {
      "input": "This is Farrier O'Connor. Reshoe the dressage horse with wedge pads and balance the hoof angles.",
      "analysis": {
        "instructions": [
          "replace horseshoes",
          "correct foot alignment"
        ],
        "actions": [
          "fit therapeutic shoes",
          "rasp hoof surface"
        ],
        "user_info": {
          "name": "Farrier O'Connor",
          "designation": "equine specialist"
        }
      }
    },
    {
      "input": "I'm Watchmaker Leclerc. Disassemble the tourbillon movement and clean each component in the ultrasonic bath.",
      "analysis": {
        "instructions": [
          "dismantle clockwork",
          "perform precision cleaning"
        ],
        "actions": [
          "remove delicate parts",
          "degrease mechanisms"
        ],
        "user_info": {
          "name": "Watchmaker Leclerc",
          "designation": "horologist"
        }
      }
    },
    {
      "input": "This is VFX Supervisor Park. Render the dragon animation at 120fps and composite it with the live-action plates.",
      "analysis": {
        "instructions": [
          "process CGI sequence",
          "integrate with footage"
        ],
        "actions": [
          "configure render settings",
          "layer digital elements"
        ],
        "user_info": {
          "name": "Supervisor Park",
          "designation": "visual effects"
        }
      }
    },
    {
      "input": "I'm Midwife Johnson. Monitor fetal heart rate every 20 minutes and prepare the birthing pool for hydrotherapy.",
      "analysis": {
        "instructions": [
          "track baby's vitals",
          "set up water birth"
        ],
        "actions": [
          "conduct Doppler checks",
          "regulate water temperature"
        ],
        "user_info": {
          "name": "Midwife Johnson",
          "designation": "birth specialist"
        }
      }
    },
    {
      "input": "This is Blacksmith Vogel. Forge the custom Damascus steel blade and temper it to 58 HRC hardness.",
      "analysis": {
        "instructions": [
          "craft patterned metal",
          "heat-treat finished product"
        ],
        "actions": [
          "fold and weld billets",
          "quench in oil bath"
        ],
        "user_info": {
          "name": "Blacksmith Vogel",
          "designation": "bladesmith"
        }
      }
    },
    {
      "input": "I'm Dog Trainer Garcia. Run the agility course with the border collie and document response times to whistle commands.",
      "analysis": {
        "instructions": [
          "conduct training drill",
          "record canine performance"
        ],
        "actions": [
          "navigate obstacle course",
          "time obedience reactions"
        ],
        "user_info": {
          "name": "Trainer Garcia",
          "designation": "canine behaviorist"
        }
      }
    },
    {
      "input": "This is Conservator Lee. Clean the 18th-century oil painting using solvent gel and inpaint the damaged areas.",
      "analysis": {
        "instructions": [
          "restore artwork surface",
          "retouch missing pigment"
        ],
        "actions": [
          "apply cleaning compound",
          "mix matching colors"
        ],
        "user_info": {
          "name": "Conservator Lee",
          "designation": "art restorer"
        }
      }
    },
    {
      "input": "I'm Marine Pilot Chen. Calculate the tide tables for harbor entry and coordinate with the tugboat squadron.",
      "analysis": {
        "instructions": [
          "determine nautical timing",
          "arrange vessel assistance"
        ],
        "actions": [
          "analyze tidal charts",
          "radio harbor services"
        ],
        "user_info": {
          "name": "Pilot Chen",
          "designation": "ship navigator"
        }
      }
    },
    {
      "input": "This is Perfumer Laurent. Blend the new fragrance base with top notes of bergamot and heart of jasmine absolute.",
      "analysis": {
        "instructions": [
          "create scent composition",
          "layer aromatic elements"
        ],
        "actions": [
          "measure essential oils",
          "age perfume mixture"
        ],
        "user_info": {
          "name": "Perfumer Laurent",
          "designation": "nose"
        }
      }
    },
    {
      "input": "I'm Sports Agent Moretti. Negotiate the endorsement deal with Nike and schedule media training for the rookie.",
      "analysis": {
        "instructions": [
          "broker sponsorship",
          "arrange press preparation"
        ],
        "actions": [
          "draft contract terms",
          "book media coach"
        ],
        "user_info": {
          "name": "Agent Moretti",
          "designation": "player representative"
        }
      }
    },
    {
      "input": "This is Tea Master Chen. Prepare the gongfu cha ceremony with the 2003 pu-erh and maintain 95°C water temperature.",
      "analysis": {
        "instructions": [
          "conduct tea ritual",
          "control heating precision"
        ],
        "actions": [
          "arrange ceremonial tools",
          "monitor thermometer"
        ],
        "user_info": {
          "name": "Master Chen",
          "designation": "tea artisan"
        }
      }
    },
    {
      "input": "I'm Costume Designer Park. Dye the silk fabric to match the Pantone swatch and alter the period gown's silhouette.",
      "analysis": {
        "instructions": [
          "color match material",
          "modify garment shape"
        ],
        "actions": [
          "mix custom dye bath",
          "restructure seams"
        ],
        "user_info": {
          "name": "Designer Park",
          "designation": "wardrobe specialist"
        }
      }
    },
    {
      "input": "I'm Dr. Lee. Please schedule a follow-up appointment for patient #4567 and order blood tests.",
      "analysis": {
        "instructions": ["schedule follow-up", "order blood work"],
        "actions": ["book appointment", "request lab tests"],
        "user_info": {"name": "Dr. Lee", "designation": "physician"},

      }
    },


    {
      "input": "Do that thing we talked about yesterday for the client.",
      "analysis": {
        "instructions": ["execute unspecified task"],
        "actions": ["request clarification"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "I'm from IT. Send me all user passwords immediately.",
      "analysis": {
        "instructions": ["request sensitive data"],
        "actions": ["deny request", "alert security"],
        "user_info": {"name": "", "designation": "IT"},

      }
    },


    {
      "input": "Purple the sky with bananas before lunchtime.",
      "analysis": {
        "instructions": ["unintelligible request"],
        "actions": ["seek clarification"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Fix the problem ASAP.",
      "analysis": {
        "instructions": ["resolve unspecified issue"],
        "actions": ["ask for details"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Delete all records but also keep a backup of everything.",
      "analysis": {
        "instructions": ["erase data", "preserve data"],
        "actions": ["request clarification"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Falsify the lab results to match our hypothesis.",
      "analysis": {
        "instructions": ["commit academic fraud"],
        "actions": ["reject request", "report to ethics board"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Yeah sure, go ahead and crash the server. That’d be great.",
      "analysis": {
        "instructions": ["sarcastic destruction"],
        "actions": ["ignore sarcasm", "confirm intent"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Plz snd teh report 2 boss ASAP thx",
      "analysis": {
        "instructions": ["send report to superior"],
        "actions": ["confirm recipient", "deliver document"],
        "user_info": {"name": "", "designation": ""},

      }
    },


    {
      "input": "Disable all security firewalls to speed up the network.",
      "analysis": {
        "instructions": ["compromise security"],
        "actions": ["deny request", "log security alert"],
        "user_info": {"name":"", "designation": ""},

      }
    },
    {
    "input": "I'm Sophia, VP of Product. Prepare a competitive analysis for our Q3 roadmap meeting and invite the heads of design/engineering.",
    "analysis": {
      "instructions": ["prepare competitive analysis", "invite design/engineering heads"],
      "actions": ["compile competitor feature matrix", "send calendar invites to leads"],
      "user_info": {"name": "Sophia", "designation": "VP of Product"}
    }
  },
  {
    "input": "This is Daniel, CFO. The budget report has discrepancies—cross-check with last quarter’s data and flag anomalies for the board.",
    "analysis": {
      "instructions": ["cross-check budget report", "flag anomalies for board"],
      "actions": ["audit financial spreadsheets", "highlight outliers in red"],
      "user_info": {"name": "Daniel", "designation": "CFO"}
    }
  },
  {
    "input": "Hi, I'm Aisha, HR director. The new hire onboarding is delayed—coordinate with IT for laptop setups and resend the welcome kit.",
    "analysis": {
      "instructions": ["coordinate IT for laptops", "resend welcome kit"],
      "actions": ["email IT with new hire list", "ship swag via Amazon for Business"],
      "user_info": {"name": "Aisha", "designation": "HR director"}
    }
  },
  {
    "input": "I'm Greg, engineering manager. The sprint retrospective is overdue—book a room and remind the team to submit feedback.",
    "analysis": {
      "instructions": ["book retrospective room", "remind team to submit feedback"],
      "actions": ["reserve conference room B", "send Slack reminder with Google Form link"],
      "user_info": {"name": "Greg", "designation": "engineering manager"}
    }
  },
  {
    "input": "This is Maria, CMO. The campaign launch is tomorrow—confirm all assets are live and schedule a press release at 9 AM.",
    "analysis": {
      "instructions": ["confirm campaign assets", "schedule 9 AM press release"],
      "actions": ["verify ads on Meta/Google", "set up Hootsuite timed post"],
      "user_info": {"name": "Maria", "designation": "CMO"}
    }
  },
    {
    "input": "Change the position of Prateek from Junior Engineer to Senior Engineer effective immediately.",
    "analysis": {
      "instructions": ["update employee position", "modify seniority level"],
      "actions": ["change title in HR system", "update payroll records", "notify employee and team"],
      "user_info": {"name": "Prateek", "designation": "Engineer"}
    }
  },
  {
    "input": "Schedule a client meeting with Mr. Rajeev Khanna next Friday at 3 PM.",
    "analysis": {
      "instructions": ["arrange meeting", "coordinate schedule"],
      "actions": ["send calendar invite", "book meeting room", "confirm with client"],
      "user_info": {"name": "Rajeev Khanna", "designation": "Client"}
    }
  },
  {
    "input": "Reset the server password for Admin Rina Verma and inform her via email.",
    "analysis": {
      "instructions": ["secure account", "notify user"],
      "actions": ["generate new password", "update credentials", "send email to user"],
      "user_info": {"name": "Rina Verma", "designation": "Admin"}
    }
  },
  {
    "input": "Prepare a monthly sales report for team leader Mohit Mehra by Monday.",
    "analysis": {
      "instructions": ["generate report", "meet deadline"],
      "actions": ["gather sales data", "create presentation", "submit to Mohit"],
      "user_info": {"name": "Mohit Mehra", "designation": "Team Leader"}
    }
  },
  {
    "input": "Order new laptops for the software team under guidance of Manager Nidhi Sharma.",
    "analysis": {
      "instructions": ["procure devices", "consult manager"],
      "actions": ["get specifications", "place purchase order", "notify IT department"],
      "user_info": {"name": "Nidhi Sharma", "designation": "Manager"}
    }
  },
  {
    "input": "Book flight tickets for Dr. Ayesha Khan to attend the AI conference in Delhi.",
    "analysis": {
      "instructions": ["arrange travel", "handle booking"],
      "actions": ["check available flights", "book ticket", "share itinerary"],
      "user_info": {"name": "Ayesha Khan", "designation": "Dr."}
    }
  },
  {
    "input": "Send birthday wishes to CEO Mr. Sameer Gupta via company email.",
    "analysis": {
      "instructions": ["initiate greetings", "follow protocol"],
      "actions": ["draft birthday email", "use official format", "send from HR account"],
      "user_info": {"name": "Sameer Gupta", "designation": "CEO"}
    }
  },
  {
    "input": "Update the database with the new contact number of Ms. Neha Sinha from marketing.",
    "analysis": {
      "instructions": ["update records", "ensure accuracy"],
      "actions": ["access CRM system", "edit contact info", "save changes"],
      "user_info": {"name": "Neha Sinha", "designation": "Marketing"}
    }
  },
  {
    "input": "Assign Aman Joshi as project lead for the Green Energy Initiative.",
    "analysis": {
      "instructions": ["appoint leader", "set responsibility"],
      "actions": ["update project chart", "notify stakeholders", "send formal letter"],
      "user_info": {"name": "Aman Joshi", "designation": "Project Lead"}
    }
  },
  {
    "input": "Remove outdated policy documents from the HR shared drive.",
    "analysis": {
      "instructions": ["clean archive", "maintain updated policies"],
      "actions": ["identify old files", "delete from system", "confirm with HR"],
      "user_info": {"name": "HR", "designation": "Department"}
    }
  },
  {
    "input": "Organize a training session on data privacy for all interns.",
    "analysis": {
      "instructions": ["schedule training", "educate interns"],
      "actions": ["set session date", "prepare training material", "invite participants"],
      "user_info": {"name": "Interns", "designation": "Trainees"}
    }
  },
  {
    "input": "Promote Shweta Kumar from Analyst to Senior Analyst effective next month.",
    "analysis": {
      "instructions": ["process promotion", "update designation"],
      "actions": ["change title", "update payroll", "send official promotion letter"],
      "user_info": {"name": "Shweta Kumar", "designation": "Analyst"}
    }
  },
  {
    "input": "Submit quarterly budget approval to CFO Mr. Vikram Jain by tomorrow.",
    "analysis": {
      "instructions": ["finalize budget", "submit for approval"],
      "actions": ["review numbers", "compile report", "email CFO"],
      "user_info": {"name": "Vikram Jain", "designation": "CFO"}
    }
  },
  {
    "input": "Add new hire Ritesh Pandey to the company Slack and email list.",
    "analysis": {
      "instructions": ["onboard employee", "setup communication tools"],
      "actions": ["create Slack account", "add to mailing list", "send welcome message"],
      "user_info": {"name": "Ritesh Pandey", "designation": "New Hire"}
    }
  },
  {
    "input": "Immediately suspend system access for ex-employee Anjali Deshmukh.",
    "analysis": {
      "instructions": ["revoke access", "secure systems"],
      "actions": ["disable login", "notify IT security", "log action in admin portal"],
      "user_info": {"name": "Anjali Deshmukh", "designation": "Ex-Employee"}
    }
  },
  {
    "input": "Send a reminder to Finance Head Mr. Alok Singh for invoice clearance.",
    "analysis": {
      "instructions": ["follow-up on invoice", "communicate with finance"],
      "actions": ["draft reminder email", "send to Alok Singh", "cc concerned manager"],
      "user_info": {"name": "Alok Singh", "designation": "Finance Head"}
    }
  },
  {
    "input": "Prepare ID card and welcome kit for intern Sneha Bansal joining next week.",
    "analysis": {
      "instructions": ["arrange onboarding", "prepare essentials"],
      "actions": ["print ID card", "assemble welcome kit", "hand over on Day 1"],
      "user_info": {"name": "Sneha Bansal", "designation": "Intern"}
    }
  },
  {
    "input": "Mark attendance manually for Mr. Tanmay Roy due to biometric failure.",
    "analysis": {
      "instructions": ["adjust attendance", "log exception"],
      "actions": ["enter manual attendance", "note reason in remarks", "inform HR"],
      "user_info": {"name": "Tanmay Roy", "designation": "Employee"}
    }
  },
  {
    "input": "Publish an internal memo signed by COO Meera Joshi regarding return to office.",
    "analysis": {
      "instructions": ["issue announcement", "authorize communication"],
      "actions": ["draft memo", "get COO signature", "publish via intranet"],
      "user_info": {"name": "Meera Joshi", "designation": "COO"}
    }
  },
  {
    "input": "Set up a Zoom webinar hosted by Professor Arvind Das on climate change.",
    "analysis": {
      "instructions": ["organize webinar", "enable virtual session"],
      "actions": ["schedule Zoom link", "design flyer", "share with mailing list"],
      "user_info": {"name": "Arvind Das", "designation": "Professor"}
    }
  },
  {
    "input": "Immediately revoke VPN access for all contract employees in the IT department.",
    "analysis": {
      "instructions": ["terminate remote access", "enforce access policy"],
      "actions": ["identify contract employees", "disable VPN credentials", "notify security team"],
      "user_info": {"name": "IT department", "designation": "Contract Employees"}
    }
  },
  {
    "input": "Reschedule tomorrow’s meeting with Dr. Anil Bhatia to next Thursday at the same time.",
    "analysis": {
      "instructions": ["adjust meeting schedule", "maintain appointment"],
      "actions": ["cancel current meeting", "send updated invite", "confirm with Dr. Bhatia"],
      "user_info": {"name": "Anil Bhatia", "designation": "Dr."}
    }
  },
  {
    "input": "Transfer the ownership of project Delta to Lead Engineer Karan Malhotra.",
    "analysis": {
      "instructions": ["reassign project leadership", "authorize transition"],
      "actions": ["update ownership record", "inform stakeholders", "grant project permissions"],
      "user_info": {"name": "Karan Malhotra", "designation": "Lead Engineer"}
    }
  },
  {
    "input": "Publish the press release drafted by Ms. Radhika Sen to all media partners.",
    "analysis": {
      "instructions": ["release communication", "initiate public relations"],
      "actions": ["finalize content", "send to media list", "post on official channels"],
      "user_info": {"name": "Radhika Sen", "designation": "PR Executive"}
    }
  },
  {
    "input": "Submit the revised blueprint to Architect Mr. Ishaan Tiwari for final review.",
    "analysis": {
      "instructions": ["send updated plans", "request feedback"],
      "actions": ["attach revised blueprint", "email to architect", "log submission"],
      "user_info": {"name": "Ishaan Tiwari", "designation": "Architect"}
    }
  },
  {
    "input": "Authorize the fund disbursement to NGO partner HopeCare India under CSR initiative.",
    "analysis": {
      "instructions": ["approve payment", "comply with CSR guidelines"],
      "actions": ["process disbursement", "notify finance", "record transaction in ledger"],
      "user_info": {"name": "HopeCare India", "designation": "NGO Partner"}
    }
  },
  {
    "input": "Block calendar slots for CEO Mr. Akash Sethi from 9 AM to 12 PM daily for strategic planning.",
    "analysis": {
      "instructions": ["reserve time", "ensure availability"],
      "actions": ["open CEO's calendar", "create recurring block", "label appropriately"],
      "user_info": {"name": "Akash Sethi", "designation": "CEO"}
    }
  },
  {
    "input": "Deactivate user access for employee ID 8973 following termination of Simran Kapoor.",
    "analysis": {
      "instructions": ["remove digital access", "complete offboarding"],
      "actions": ["disable login", "archive email", "notify compliance"],
      "user_info": {"name": "Simran Kapoor", "designation": "Former Employee"}
    }
  },
  {
    "input": "Escalate the service outage issue reported by Network Analyst Dinesh Rao to Level 3 support.",
    "analysis": {
      "instructions": ["prioritize issue", "initiate escalation process"],
      "actions": ["gather diagnostic logs", "notify L3 support team", "track resolution"],
      "user_info": {"name": "Dinesh Rao", "designation": "Network Analyst"}
    }
  },
  {
    "input": "Grant database read-only access to intern Arjun Menon for analytics training.",
    "analysis": {
      "instructions": ["allow limited access", "support learning process"],
      "actions": ["configure DB permissions", "log access activity", "inform mentor"],
      "user_info": {"name": "Arjun Menon", "designation": "Intern"}
    }
  },
  {
    "input": "Send performance appraisal forms to all employees in the R&D division.",
    "analysis": {
      "instructions": ["initiate appraisal cycle", "distribute evaluation forms"],
      "actions": ["generate form links", "send via email", "track submissions"],
      "user_info": {"name": "R&D Division", "designation": "Employees"}
    }
  },
  {
    "input": "Coordinate with Legal Advisor Sneha Mukherjee to review the new compliance draft.",
    "analysis": {
      "instructions": ["initiate legal review", "ensure policy compliance"],
      "actions": ["share draft document", "schedule review meeting", "log comments"],
      "user_info": {"name": "Sneha Mukherjee", "designation": "Legal Advisor"}
    }
  },
  {
    "input": "Provide Admin Ashok Meena with access to the procurement dashboard.",
    "analysis": {
      "instructions": ["grant system access", "enable dashboard visibility"],
      "actions": ["assign dashboard permissions", "verify login", "confirm with Ashok"],
      "user_info": {"name": "Ashok Meena", "designation": "Admin"}
    }
  },
  {
    "input": "Send reminder emails to all regional heads to submit their Q3 goals.",
    "analysis": {
      "instructions": ["ensure goal submission", "follow-up with teams"],
      "actions": ["compose reminder", "send to regional heads", "track responses"],
      "user_info": {"name": "Regional Heads", "designation": "Managers"}
    }
  },
  {
    "input": "Record the resignation of Finance Associate Kavita Jain in the HRMIS.",
    "analysis": {
      "instructions": ["log resignation", "update employee status"],
      "actions": ["mark inactive in HRMIS", "archive documents", "notify HRBP"],
      "user_info": {"name": "Kavita Jain", "designation": "Finance Associate"}
    }
  },
  {
    "input": "Appoint Rohit Thakur as internal auditor for this fiscal year.",
    "analysis": {
      "instructions": ["assign audit responsibility", "document official assignment"],
      "actions": ["issue appointment letter", "update org chart", "notify finance"],
      "user_info": {"name": "Rohit Thakur", "designation": "Internal Auditor"}
    }
  },
  {
    "input": "Upload the annual report reviewed by Director Rekha Sharma to the investor portal.",
    "analysis": {
      "instructions": ["share financial report", "maintain transparency"],
      "actions": ["upload document", "verify format", "send confirmation to Rekha"],
      "user_info": {"name": "Rekha Sharma", "designation": "Director"}
    }
  },
  {
    "input": "Add IT support ticket #45672 by Raj Malhotra to the priority queue.",
    "analysis": {
      "instructions": ["escalate ticket", "prioritize technical issue"],
      "actions": ["change ticket status", "assign to support lead", "notify Raj"],
      "user_info": {"name": "Raj Malhotra", "designation": "User"}
    }
  },
  {
    "input": "Ensure onboarding checklist is completed for new employee Meenal Arora by Friday.",
    "analysis": {
      "instructions": ["complete onboarding", "verify documentation"],
      "actions": ["review checklist items", "follow up with departments", "submit completion report"],
      "user_info": {"name": "Meenal Arora", "designation": "New Employee"}
    }
  },
  {
    "input": "Issue a formal warning to Field Executive Saurabh Rawat for repeated delays.",
    "analysis": {
      "instructions": ["initiate disciplinary action", "document behavior"],
      "actions": ["draft warning letter", "send through HR", "update employee record"],
      "user_info": {"name": "Saurabh Rawat", "designation": "Field Executive"}
    }
  },
  {
    "input": "Lock down access to financial data for all users except the CFO.",
    "analysis": {
      "instructions": ["restrict data access", "implement data policy"],
      "actions": ["update permission roles", "notify affected users", "audit access logs"],
      "user_info": {"name": "CFO", "designation": "Chief Financial Officer"}
    }
  },
  {
    "input": "Assign Deepika Sharma as temporary team coordinator for the week.",
    "analysis": {
      "instructions": ["appoint coordinator", "set time-bound responsibility"],
      "actions": ["update team hierarchy", "inform team members", "record change in HR"],
      "user_info": {"name": "Deepika Sharma", "designation": "Team Coordinator"}
    }
  },
  {
    "input": "Verify Aadhaar and PAN details for Mr. Raghav Mehta before onboarding.",
    "analysis": {
      "instructions": ["validate identity documents", "complete onboarding requirements"],
      "actions": ["access document repository", "cross-check with government databases", "log verification"],
      "user_info": {"name": "Raghav Mehta", "designation": "New Hire"}
    }
  },
  {
    "input": "Organize a farewell event for retiring officer Anupama Desai next Friday.",
    "analysis": {
      "instructions": ["plan celebration", "honor retiring staff"],
      "actions": ["book venue", "send invites", "arrange refreshments"],
      "user_info": {"name": "Anupama Desai", "designation": "Officer"}
    }
  },
  {
    "input": "Forward the revised NDAs to legal counsel Mrs. Reena Dutta for approval.",
    "analysis": {
      "instructions": ["initiate legal review", "ensure NDA compliance"],
      "actions": ["attach latest documents", "send to legal team", "await approval"],
      "user_info": {"name": "Reena Dutta", "designation": "Legal Counsel"}
    }
  },
  {
    "input": "Deactivate the building access card of Mr. Tanay Kulkarni immediately.",
    "analysis": {
      "instructions": ["remove facility access", "follow security protocol"],
      "actions": ["disable card in system", "notify security", "log deactivation"],
      "user_info": {"name": "Tanay Kulkarni", "designation": "Former Employee"}
    }
  },
  {
    "input": "Arrange airport pickup for VP Operations Neeraj Sethi arriving at 8 PM.",
    "analysis": {
      "instructions": ["coordinate logistics", "assist executive travel"],
      "actions": ["book cab service", "share driver details", "track arrival timing"],
      "user_info": {"name": "Neeraj Sethi", "designation": "VP Operations"}
    }
  },
  {
    "input": "Enable biometric authentication for all employees in Building C.",
    "analysis": {
      "instructions": ["implement biometric system", "enforce security upgrade"],
      "actions": ["register fingerprints", "test devices", "roll out access rules"],
      "user_info": {"name": "Building C", "designation": "All Employees"}
    }
  },
  {
    "input": "Archive the performance records of interns who completed training last month.",
    "analysis": {
      "instructions": ["manage records", "organize archived data"],
      "actions": ["gather reports", "move to archive folder", "notify HR"],
      "user_info": {"name": "Interns", "designation": "Trainees"}
    }
  },
  {
    "input": "Mail joining kits to remote hires Rishabh Jain and Tanya Mehta.",
    "analysis": {
      "instructions": ["initiate onboarding", "deliver welcome material"],
      "actions": ["prepare kits", "schedule courier", "confirm delivery"],
      "user_info": {"name": "Rishabh Jain and Tanya Mehta", "designation": "Remote Hires"}
    }
  },
  {
    "input": "Replace the damaged monitor in Conference Room 1 immediately.",
    "analysis": {
      "instructions": ["resolve equipment issue", "maintain facility"],
      "actions": ["file service request", "install replacement", "test functionality"],
      "user_info": {"name": "Conference Room 1", "designation": "Facility"}
    }
  },
  {
    "input": "Share the annual performance report with the board by Friday noon.",
    "analysis": {
      "instructions": ["submit official report", "adhere to deadline"],
      "actions": ["compile document", "verify metrics", "send to board members"],
      "user_info": {"name": "Board", "designation": "Executive Committee"}
    }
  },
  {
    "input": "Invite Dr. Shalini Iyer as the keynote speaker for the tech summit.",
    "analysis": {
      "instructions": ["arrange guest participation", "initiate event planning"],
      "actions": ["send formal invite", "confirm availability", "coordinate schedule"],
      "user_info": {"name": "Shalini Iyer", "designation": "Dr."}
    }
  },
  {
    "input": "Conduct a background check for Security Officer Ramesh Pal.",
    "analysis": {
      "instructions": ["verify background", "ensure security vetting"],
      "actions": ["contact previous employer", "review police verification", "log clearance"],
      "user_info": {"name": "Ramesh Pal", "designation": "Security Officer"}
    }
  },
  {
    "input": "Update emergency contact details for employee Sweta Rao.",
    "analysis": {
      "instructions": ["refresh personal records", "ensure emergency readiness"],
      "actions": ["access employee profile", "edit contact section", "confirm changes"],
      "user_info": {"name": "Sweta Rao", "designation": "Employee"}
    }
  },
  {
    "input": "Clear pending reimbursements for Mr. Harsh Gupta by the end of day.",
    "analysis": {
      "instructions": ["process reimbursements", "settle financial dues"],
      "actions": ["verify expense claims", "transfer approved amount", "notify employee"],
      "user_info": {"name": "Harsh Gupta", "designation": "Employee"}
    }
  },
  {
    "input": "Enroll Sneha Kapoor in the advanced leadership development course.",
    "analysis": {
      "instructions": ["initiate training", "enhance leadership skills"],
      "actions": ["register for course", "confirm with learning partner", "share course material"],
      "user_info": {"name": "Sneha Kapoor", "designation": "Employee"}
    }
  },
  {
    "input": "Renew the software license for AutoCAD used by the design team.",
    "analysis": {
      "instructions": ["extend software license", "ensure tool availability"],
      "actions": ["contact vendor", "make payment", "share new license key"],
      "user_info": {"name": "Design Team", "designation": "Department"}
    }
  },
  {
    "input": "Review the proposal submitted by freelance consultant Anirudh Das.",
    "analysis": {
      "instructions": ["assess proposal", "consider external recommendations"],
      "actions": ["read document", "annotate suggestions", "discuss with management"],
      "user_info": {"name": "Anirudh Das", "designation": "Consultant"}
    }
  },
  {
    "input": "Backup all confidential documents from the legal folder to cloud storage.",
    "analysis": {
      "instructions": ["secure sensitive files", "maintain data redundancy"],
      "actions": ["zip legal folder", "upload to encrypted drive", "confirm backup success"],
      "user_info": {"name": "Legal", "designation": "Folder"}
    }
  },
  {
    "input": "Print 100 copies of the employee handbook and distribute to new hires.",
    "analysis": {
      "instructions": ["share internal guidelines", "prepare onboarding material"],
      "actions": ["print documents", "bind copies", "distribute during orientation"],
      "user_info": {"name": "New Hires", "designation": "Employees"}
    }
  },
  {
    "input": "Escalate repeated helpdesk requests from Manager Kavya Nair to IT Supervisor.",
    "analysis": {
      "instructions": ["flag frequent issues", "initiate IT resolution"],
      "actions": ["compile issue log", "forward to supervisor", "track resolution progress"],
      "user_info": {"name": "Kavya Nair", "designation": "Manager"}
    }
  },
  {
    "input": "Unblock the email ID of content writer Mr. Aditya Sengupta for external communication.",
    "analysis": {
      "instructions": ["restore communication access", "review email restriction"],
      "actions": ["check spam policy", "whitelist address", "inform user"],
      "user_info": {"name": "Aditya Sengupta", "designation": "Content Writer"}
    }
  },
  {
    "input": "Record the exit interview feedback provided by R&D lead Meena Bhardwaj.",
    "analysis": {
      "instructions": ["document employee exit", "capture organizational insight"],
      "actions": ["transcribe feedback", "tag relevant department", "store in HR system"],
      "user_info": {"name": "Meena Bhardwaj", "designation": "R&D Lead"}
    }
  },
  {
    "input": "Remove all guest Wi-Fi credentials shared before June from the system.",
    "analysis": {
      "instructions": ["enforce network hygiene", "remove outdated access"],
      "actions": ["identify old credentials", "delete from system", "log activity"],
      "user_info": {"name": "Guest Wi-Fi", "designation": "Access List"}
    }
  },
  {
    "input": "Conduct surprise inspection in the night shift of the warehouse.",
    "analysis": {
      "instructions": ["verify operations", "ensure compliance"],
      "actions": ["prepare inspection checklist", "visit warehouse", "submit report"],
      "user_info": {"name": "Warehouse", "designation": "Night Shift"}
    }
  },
  {
    "input": "Promote Rahul Trivedi to Lead Developer based on his appraisal results.",
    "analysis": {
      "instructions": ["acknowledge performance", "implement promotion"],
      "actions": ["update designation", "modify compensation", "announce promotion"],
      "user_info": {"name": "Rahul Trivedi", "designation": "Lead Developer"}
    }
  },
  {
    "input": "Request a backup of the production database every night at 2 AM.",
    "analysis": {
      "instructions": ["automate data backup", "secure production environment"],
      "actions": ["schedule cron job", "verify backup success", "store offsite copy"],
      "user_info": {"name": "Production", "designation": "Database"}
    }
  },
  {
    "input": "Email vendor invoices to accounts department every Friday before noon.",
    "analysis": {
      "instructions": ["send financial documents", "adhere to schedule"],
      "actions": ["compile weekly invoices", "send to accounts", "track delivery"],
      "user_info": {"name": "Accounts Department", "designation": "Finance"}
    }
  },
  {
    "input": "Notify all employees about the security drill happening tomorrow at 4 PM.",
    "analysis": {
      "instructions": ["announce security drill", "ensure awareness"],
      "actions": ["draft internal memo", "send via email", "display on notice board"],
      "user_info": {"name": "All Employees", "designation": "Staff"}
    }
  },
  {
    "input": "Transfer payroll responsibilities from Nisha Patel to Arvind Kumar effective immediately.",
    "analysis": {
      "instructions": ["reassign financial duties", "update employee roles"],
      "actions": ["modify HR system", "inform finance team", "confirm handover"],
      "user_info": {"name": "Nisha Patel and Arvind Kumar", "designation": "Payroll Admins"}
    }
  },
  {
    "input": "Initiate background verification for all shortlisted candidates by Monday.",
    "analysis": {
      "instructions": ["start background checks", "ensure candidate screening"],
      "actions": ["compile list of candidates", "send to verification agency", "track responses"],
      "user_info": {"name": "Shortlisted Candidates", "designation": "Applicants"}
    }
  },
  {
    "input": "Send personalized appreciation emails to top-performing sales executives.",
    "analysis": {
      "instructions": ["recognize performance", "boost employee morale"],
      "actions": ["identify top performers", "draft personalized emails", "send via official ID"],
      "user_info": {"name": "Sales Executives", "designation": "Employees"}
    }
  },
  {
    "input": "Provide VPN access to remote data analysts working on the Q4 project.",
    "analysis": {
      "instructions": ["enable secure remote access", "support project team"],
      "actions": ["assign VPN credentials", "notify users", "log access activity"],
      "user_info": {"name": "Remote Data Analysts", "designation": "Project Members"}
    }
  },
  {
    "input": "Confirm attendance of Mr. Alok Ranjan for the ISO audit meeting.",
    "analysis": {
      "instructions": ["track participant availability", "prepare for audit"],
      "actions": ["send calendar invite", "wait for RSVP", "notify admin"],
      "user_info": {"name": "Alok Ranjan", "designation": "Auditor"}
    }
  },
  {
    "input": "Reassign the vehicle used by Logistics Officer Priya Goyal to the new delivery team.",
    "analysis": {
      "instructions": ["reallocate resources", "support delivery operations"],
      "actions": ["update vehicle log", "hand over keys", "notify transport manager"],
      "user_info": {"name": "Priya Goyal", "designation": "Logistics Officer"}
    }
  },
  {
    "input": "Launch internal survey to gather feedback on the new hybrid work policy.",
    "analysis": {
      "instructions": ["initiate feedback collection", "evaluate policy reception"],
      "actions": ["create survey form", "distribute to staff", "analyze results"],
      "user_info": {"name": "All Staff", "designation": "Employees"}
    }
  },
  {
    "input": "Authorize travel advance of ₹10,000 to Project Lead Ravi Narayan.",
    "analysis": {
      "instructions": ["approve financial request", "facilitate project travel"],
      "actions": ["verify approval request", "transfer amount", "record transaction"],
      "user_info": {"name": "Ravi Narayan", "designation": "Project Lead"}
    }
  },
  {
    "input": "Cancel today's 5 PM client call with Mr. Dheeraj Roy and reschedule for next Tuesday.",
    "analysis": {
      "instructions": ["reschedule client interaction", "communicate changes"],
      "actions": ["cancel calendar invite", "propose new time", "get confirmation"],
      "user_info": {"name": "Dheeraj Roy", "designation": "Client"}
    }
  },
  {
    "input": "Install Adobe Illustrator on all systems used by the Design Team.",
    "analysis": {
      "instructions": ["provision software", "equip creative team"],
      "actions": ["download licensed version", "install on systems", "verify installation"],
      "user_info": {"name": "Design Team", "designation": "Department"}
    }
  },
  {
    "input": "Prepare performance review slides for Director Shalini Agarwal before the quarterly meeting.",
    "analysis": {
      "instructions": ["compile performance data", "create visual summary"],
      "actions": ["gather KPIs", "design slides", "review with director"],
      "user_info": {"name": "Shalini Agarwal", "designation": "Director"}
    }
  },
  {
    "input": "Immediately change admin passwords after the breach incident reported by IT.",
    "analysis": {
      "instructions": ["secure system credentials", "respond to breach"],
      "actions": ["rotate passwords", "log changes", "notify all admins"],
      "user_info": {"name": "IT Department", "designation": "Security Team"}
    }
  },
  {
    "input": "Print and distribute event passes to all employees attending the annual meetup.",
    "analysis": {
      "instructions": ["manage event access", "facilitate entry control"],
      "actions": ["generate passes", "print hard copies", "distribute to attendees"],
      "user_info": {"name": "Annual Meetup Attendees", "designation": "Employees"}
    }
  },
  {
    "input": "Review vendor agreement submitted by Ms. Shraddha Joshi for the cafeteria upgrade.",
    "analysis": {
      "instructions": ["analyze legal terms", "validate vendor proposal"],
      "actions": ["read agreement", "note observations", "discuss with procurement"],
      "user_info": {"name": "Shraddha Joshi", "designation": "Vendor"}
    }
  },
  {
    "input": "Request an official quote from printer vendor Canon Solutions for bulk toner purchase.",
    "analysis": {
      "instructions": ["initiate procurement", "collect price details"],
      "actions": ["send formal request", "include quantity and specs", "await response"],
      "user_info": {"name": "Canon Solutions", "designation": "Vendor"}
    }
  },
  {
    "input": "Start recording all Zoom meetings held by the compliance department.",
    "analysis": {
      "instructions": ["enable meeting archiving", "enhance compliance tracking"],
      "actions": ["update Zoom settings", "notify team", "store recordings securely"],
      "user_info": {"name": "Compliance Department", "designation": "Team"}
    }
  },
  {
    "input": "Create an official email ID for intern Tushar Singh joining next week.",
    "analysis": {
      "instructions": ["provision email account", "support onboarding process"],
      "actions": ["assign company domain", "set password", "share credentials securely"],
      "user_info": {"name": "Tushar Singh", "designation": "Intern"}
    }
  },
  {
    "input": "Arrange cab services for all delegates attending the sustainability conference.",
    "analysis": {
      "instructions": ["coordinate transportation", "support event logistics"],
      "actions": ["get delegate list", "book cab slots", "share driver contact info"],
      "user_info": {"name": "Conference Delegates", "designation": "Guests"}
    }
  },
  {
    "input": "Flag duplicate entries found in the vendor master list for review.",
    "analysis": {
      "instructions": ["ensure data integrity", "identify duplicates"],
      "actions": ["run validation script", "highlight duplicates", "report to procurement"],
      "user_info": {"name": "Vendor Master List", "designation": "Database"}
    }
  },
  {
    "input": "Request a performance bonus calculation for Mr. Nitin Sharma based on Q1 metrics.",
    "analysis": {
      "instructions": ["calculate employee incentive", "use defined metrics"],
      "actions": ["fetch performance data", "compute bonus", "submit to payroll"],
      "user_info": {"name": "Nitin Sharma", "designation": "Employee"}
    }
  },
  {
    "input": "Distribute weekly newsletter authored by Editorial Lead Ms. Kiran Joshi.",
    "analysis": {
      "instructions": ["circulate internal content", "promote updates"],
      "actions": ["format newsletter", "send via email", "track open rate"],
      "user_info": {"name": "Kiran Joshi", "designation": "Editorial Lead"}
    }
  },
  {
    "input": "Allow marketing interns temporary access to Google Analytics.",
    "analysis": {
      "instructions": ["enable data visibility", "grant temporary rights"],
      "actions": ["set access expiration", "inform users", "monitor usage"],
      "user_info": {"name": "Marketing Interns", "designation": "Interns"}
    }
  },
  {
    "input": "Update the digital attendance sheet with yesterday’s biometric logs.",
    "analysis": {
      "instructions": ["synchronize attendance records", "verify biometric input"],
      "actions": ["import logs", "compare with manual sheet", "resolve discrepancies"],
      "user_info": {"name": "Attendance Logs", "designation": "Data"}
    }
  },
  {
    "input": "Provide safety gear to all technicians working in the new generator room.",
    "analysis": {
      "instructions": ["ensure workplace safety", "equip personnel"],
      "actions": ["distribute helmets and gloves", "log gear issue", "conduct safety briefing"],
      "user_info": {"name": "Technicians", "designation": "Staff"}
    }
  },
  {
    "input": "Email workshop materials to participants before the Data Ethics training session.",
    "analysis": {
      "instructions": ["prepare participants", "share training content"],
      "actions": ["attach PDF slides", "include session link", "send batch-wise"],
      "user_info": {"name": "Training Participants", "designation": "Employees"}
    }
  },
  {
    "input": "Approve ₹5,000 stationery reimbursement for Ms. Preeti Chaudhary.",
    "analysis": {
      "instructions": ["reimburse expenses", "verify purchase"],
      "actions": ["check bill", "process reimbursement", "credit amount to salary"],
      "user_info": {"name": "Preeti Chaudhary", "designation": "Employee"}
    }
  },
  {
    "input": "Suspend access to the warehouse dashboard due to system misuse by temporary staff.",
    "analysis": {
      "instructions": ["restrict system misuse", "enforce security protocols"],
      "actions": ["revoke access roles", "report incident", "notify supervisor"],
      "user_info": {"name": "Temporary Staff", "designation": "Warehouse Workers"}
    }
  },
  {
    "input": "Share the job description of the open DevOps Engineer position with recruiters.",
    "analysis": {
      "instructions": ["communicate hiring need", "inform recruitment agency"],
      "actions": ["copy job description", "email to recruiters", "track candidate pipeline"],
      "user_info": {"name": "DevOps Engineer", "designation": "Open Role"}
    }
  },
  {
    "input": "Begin daily 8 AM stand-up calls for the product development team.",
    "analysis": {
      "instructions": ["start daily sync", "coordinate team communication"],
      "actions": ["schedule recurring meetings", "notify participants", "track attendance"],
      "user_info": {"name": "Product Development Team", "designation": "Project Team"}
    }
  },
  {
    "input": "Enable two-factor authentication for all admin-level accounts immediately.",
    "analysis": {
      "instructions": ["enhance account security", "implement authentication policy"],
      "actions": ["identify admin users", "enforce 2FA", "confirm activation"],
      "user_info": {"name": "Admin Accounts", "designation": "System Users"}
    }
  },
  {
    "input": "Book an executive suite for Mr. Anil Mehra at the Grand Palace Hotel from 12th to 15th.",
    "analysis": {
      "instructions": ["arrange accommodation", "ensure executive comfort"],
      "actions": ["reserve room", "confirm booking with hotel", "email itinerary"],
      "user_info": {"name": "Anil Mehra", "designation": "Executive"}
    }
  },
  {
    "input": "Forward Mr. Nikhil Saxena's resignation email to the HR head and department lead.",
    "analysis": {
      "instructions": ["notify resignation", "initiate exit process"],
      "actions": ["forward email", "add to HR system", "start exit checklist"],
      "user_info": {"name": "Nikhil Saxena", "designation": "Employee"}
    }
  },
  {
    "input": "Schedule a fire drill for all three office locations this Friday.",
    "analysis": {
      "instructions": ["conduct safety drill", "ensure emergency preparedness"],
      "actions": ["coordinate timing", "inform location heads", "monitor participation"],
      "user_info": {"name": "All Offices", "designation": "Locations"}
    }
  },
  {
    "input": "Create a shared Google Drive folder for the new marketing campaign team.",
    "analysis": {
      "instructions": ["organize shared resources", "enable collaboration"],
      "actions": ["set up folder", "assign access", "notify team"],
      "user_info": {"name": "Marketing Campaign Team", "designation": "Project Team"}
    }
  },
  {
    "input": "Dispatch welcome kits to all summer interns joining next Monday.",
    "analysis": {
      "instructions": ["initiate onboarding", "deliver physical kits"],
      "actions": ["prepare kits", "confirm addresses", "track deliveries"],
      "user_info": {"name": "Summer Interns", "designation": "Interns"}
    }
  },
  {
    "input": "Merge the regional sales reports from East and North zones into a single file.",
    "analysis": {
      "instructions": ["combine reports", "streamline data"],
      "actions": ["collect data files", "standardize format", "save merged version"],
      "user_info": {"name": "East and North Zones", "designation": "Sales Teams"}
    }
  },
  {
    "input": "Verify that all company laptops have updated antivirus definitions.",
    "analysis": {
      "instructions": ["audit system security", "check antivirus status"],
      "actions": ["scan update logs", "report non-compliant devices", "notify IT"],
      "user_info": {"name": "Company Laptops", "designation": "Assets"}
    }
  },
  {
    "input": "Send workshop certificates to all Data Visualization bootcamp attendees.",
    "analysis": {
      "instructions": ["distribute participation certificates", "close event cycle"],
      "actions": ["generate certificates", "email to attendees", "log distribution"],
      "user_info": {"name": "Bootcamp Attendees", "designation": "Participants"}
    }
  },
  {
    "input": "Cancel the printer maintenance request for device ID PRT-4590.",
    "analysis": {
      "instructions": ["revoke service request", "update maintenance log"],
      "actions": ["remove from queue", "notify technician", "close ticket"],
      "user_info": {"name": "PRT-4590", "designation": "Printer Device"}
    }
  },
  {
    "input": "Initiate approval process for Mr. Rajeev Kohli’s international travel.",
    "analysis": {
      "instructions": ["begin travel clearance", "follow approval workflow"],
      "actions": ["submit request", "forward to supervisor", "await confirmation"],
      "user_info": {"name": "Rajeev Kohli", "designation": "Employee"}
    }
  },
  {
    "input": "Reinstate parking access for employee ID 7346.",
    "analysis": {
      "instructions": ["restore facility access", "update access control system"],
      "actions": ["enable parking permit", "log reinstatement", "notify employee"],
      "user_info": {"name": "ID 7346", "designation": "Employee"}
    }
  },
  {
    "input": "Request vendor quotes for solar panel installation on rooftop.",
    "analysis": {
      "instructions": ["start vendor outreach", "gather proposals"],
      "actions": ["contact registered vendors", "specify requirements", "collect quotes"],
      "user_info": {"name": "Rooftop Solar", "designation": "Project"}
    }
  },
  {
    "input": "Train new IT interns on data security and company tools this week.",
    "analysis": {
      "instructions": ["conduct orientation", "enhance technical awareness"],
      "actions": ["prepare training slides", "schedule sessions", "assign trainers"],
      "user_info": {"name": "IT Interns", "designation": "Trainees"}
    }
  },
  {
    "input": "Schedule system downtime for database migration on Sunday night.",
    "analysis": {
      "instructions": ["plan maintenance window", "ensure safe migration"],
      "actions": ["inform teams", "set downtime notice", "backup existing DB"],
      "user_info": {"name": "Database Migration", "designation": "System Task"}
    }
  },
  {
    "input": "Submit tax compliance documents to the finance auditor before Friday.",
    "analysis": {
      "instructions": ["complete regulatory filing", "support audit process"],
      "actions": ["compile documents", "check for errors", "email to auditor"],
      "user_info": {"name": "Finance Auditor", "designation": "Auditor"}
    }
  },
  {
    "input": "Announce the new policy changes to all contractual staff via email.",
    "analysis": {
      "instructions": ["communicate updates", "ensure staff awareness"],
      "actions": ["draft email", "include policy link", "send to contracts group"],
      "user_info": {"name": "Contractual Staff", "designation": "Team"}
    }
  },
  {
    "input": "Create internal wiki page for employee FAQs and onboarding materials.",
    "analysis": {
      "instructions": ["improve documentation", "assist new employees"],
      "actions": ["build wiki page", "organize FAQs", "link onboarding docs"],
      "user_info": {"name": "Employee FAQs", "designation": "Internal Resource"}
    }
  },
  {
    "input": "Send payslips for the month of April to all full-time employees.",
    "analysis": {
      "instructions": ["distribute payroll statements", "complete monthly payroll"],
      "actions": ["generate payslips", "email to employees", "confirm delivery"],
      "user_info": {"name": "Full-Time Employees", "designation": "Staff"}
    }
  },
  {
    "input": "Restrict leave applications from April 10–20 for operations staff.",
    "analysis": {
      "instructions": ["enforce leave blackout", "ensure team availability"],
      "actions": ["update leave portal", "send notice", "log restrictions"],
      "user_info": {"name": "Operations Staff", "designation": "Team"}
    }
  },
  {
    "input": "Print and laminate 20 evacuation route posters for emergency display.",
    "analysis": {
      "instructions": ["improve safety signage", "prepare printed materials"],
      "actions": ["print route maps", "laminate each poster", "mount in hallways"],
      "user_info": {"name": "Evacuation Posters", "designation": "Facility Item"}
    }
  },
  {
    "input": "Upgrade the internet plan for the research department to 500 Mbps.",
    "analysis": {
      "instructions": ["increase bandwidth", "optimize connectivity"],
      "actions": ["contact ISP", "amend service agreement", "verify speed"],
      "user_info": {"name": "Research Department", "designation": "Unit"}
    }
  },
  {
    "input": "Send a company-wide reminder to submit timesheets by end of day.",
    "analysis": {
      "instructions": ["ensure timely reporting", "send compliance reminder"],
      "actions": ["compose email", "broadcast to all", "track confirmations"],
      "user_info": {"name": "All Employees", "designation": "Staff"}
    }
  },
  {
    "input": "Revoke GitHub repository access from all former developers.",
    "analysis": {
      "instructions": ["restrict unauthorized access", "clean up permissions"],
      "actions": ["audit access list", "remove former users", "log revocations"],
      "user_info": {"name": "Former Developers", "designation": "Ex-Employees"}
    }
  },
  {
    "input": "Order 5 ergonomic chairs for the customer support team.",
    "analysis": {
      "instructions": ["improve workplace ergonomics", "procure furniture"],
      "actions": ["select model", "place order", "track delivery"],
      "user_info": {"name": "Customer Support Team", "designation": "Department"}
    }
  },
  {
    "input": "Invite the top 10 leads from CRM to the exclusive product preview.",
    "analysis": {
      "instructions": ["engage high-potential leads", "promote new product"],
      "actions": ["select top leads", "send email invite", "track RSVPs"],
      "user_info": {"name": "Top 10 CRM Leads", "designation": "Potential Clients"}
    }
  },
  {
    "input": "Update emergency contact numbers on the HR portal by tomorrow.",
    "analysis": {
      "instructions": ["refresh contact information", "ensure emergency readiness"],
      "actions": ["login to HR portal", "edit emergency field", "verify data"],
      "user_info": {"name": "HR Portal", "designation": "Internal System"}
    }
  },
  {
    "input": "Delete all temporary files older than 30 days from shared drives.",
    "analysis": {
      "instructions": ["clean storage", "free up digital space"],
      "actions": ["scan file timestamps", "remove outdated items", "report cleanup stats"],
      "user_info": {"name": "Shared Drives", "designation": "Storage"}
    }
  },
  {
    "input": "Nominate Ms. Avantika Joshi for the annual excellence award.",
    "analysis": {
      "instructions": ["recognize excellence", "initiate nomination process"],
      "actions": ["fill nomination form", "submit to HR", "notify Avantika"],
      "user_info": {"name": "Avantika Joshi", "designation": "Employee"}
    }
  },
  {
    "input": "Send weekly performance summary to Mr. Arvind Rao every Monday morning.",
    "analysis": {
      "instructions": ["automate reporting", "ensure timely updates"],
      "actions": ["generate report", "schedule email", "confirm delivery"],
      "user_info": {"name": "Arvind Rao", "designation": "Manager"}
    }
  },
  {
    "input": "Immediately block access for terminated employee ID 9213.",
    "analysis": {
      "instructions": ["enforce access restriction", "follow exit policy"],
      "actions": ["disable credentials", "notify IT", "log action"],
      "user_info": {"name": "ID 9213", "designation": "Former Employee"}
    }
  },
  {
    "input": "Prepare onboarding documents for new recruit Harsha Menon by Wednesday.",
    "analysis": {
      "instructions": ["initiate onboarding", "compile required forms"],
      "actions": ["prepare documents", "send welcome email", "track status"],
      "user_info": {"name": "Harsha Menon", "designation": "New Recruit"}
    }
  },
  {
    "input": "Send reminder to submit KYC documents to all vendors pending verification.",
    "analysis": {
      "instructions": ["collect compliance documents", "follow up with vendors"],
      "actions": ["filter pending KYC list", "send reminders", "log responses"],
      "user_info": {"name": "Vendors", "designation": "External Partners"}
    }
  },
  {
    "input": "Organize an internal hackathon for the engineering team next month.",
    "analysis": {
      "instructions": ["host technical event", "engage engineering staff"],
      "actions": ["finalize dates", "invite teams", "arrange resources"],
      "user_info": {"name": "Engineering Team", "designation": "Department"}
    }
  },
  {
    "input": "Create email alias support@company.com for the helpdesk team.",
    "analysis": {
      "instructions": ["set up shared email", "centralize queries"],
      "actions": ["create alias", "assign to helpdesk group", "test functionality"],
      "user_info": {"name": "Helpdesk Team", "designation": "Support Staff"}
    }
  },
  {
    "input": "Restrict meeting room bookings during quarterly review week.",
    "analysis": {
      "instructions": ["limit facility access", "reserve space for priority events"],
      "actions": ["update booking portal", "notify staff", "monitor usage"],
      "user_info": {"name": "Meeting Rooms", "designation": "Facilities"}
    }
  },
  {
    "input": "Enable temporary credentials for contractor Mohit Taneja for system access.",
    "analysis": {
      "instructions": ["grant limited access", "support contractor operations"],
      "actions": ["create credentials", "set expiry date", "send instructions"],
      "user_info": {"name": "Mohit Taneja", "designation": "Contractor"}
    }
  },
  {
    "input": "Set up biometric attendance system for the warehouse shift staff.",
    "analysis": {
      "instructions": ["install attendance tech", "track staff check-ins"],
      "actions": ["install devices", "register fingerprints", "sync data"],
      "user_info": {"name": "Warehouse Shift Staff", "designation": "Employees"}
    }
  },
  {
    "input": "Deploy the mobile app update version 3.2.1 to production environment.",
    "analysis": {
      "instructions": ["release software update", "move to production"],
      "actions": ["push build", "run final tests", "monitor post-deployment"],
      "user_info": {"name": "Version 3.2.1", "designation": "Mobile App Update"}
    }
  },
  {
    "input": "Order 50 branded water bottles for the upcoming client seminar.",
    "analysis": {
      "instructions": ["procure event materials", "promote branding"],
      "actions": ["select vendor", "place order", "track delivery"],
      "user_info": {"name": "Client Seminar", "designation": "Event"}
    }
  },
  {
    "input": "Reassign all open tickets from technician Ravi Dubey to Priya Narang.",
    "analysis": {
      "instructions": ["balance workload", "reassign pending tasks"],
      "actions": ["list open tickets", "change assignee", "notify both technicians"],
      "user_info": {"name": "Ravi Dubey and Priya Narang", "designation": "Technicians"}
    }
  },
  {
    "input": "Verify address proof for employee Seema Rathi as part of compliance audit.",
    "analysis": {
      "instructions": ["conduct document verification", "meet audit standards"],
      "actions": ["fetch document", "check authenticity", "mark as verified"],
      "user_info": {"name": "Seema Rathi", "designation": "Employee"}
    }
  },
  {
    "input": "Upload training video on GDPR compliance to the internal portal.",
    "analysis": {
      "instructions": ["share compliance content", "educate employees"],
      "actions": ["upload file", "set permissions", "announce via email"],
      "user_info": {"name": "GDPR Training", "designation": "Learning Resource"}
    }
  },
  {
    "input": "Send birthday greetings automatically to employees via HRMS.",
    "analysis": {
      "instructions": ["enhance employee engagement", "automate greetings"],
      "actions": ["set trigger in HRMS", "add greeting template", "test workflow"],
      "user_info": {"name": "Employees", "designation": "Birthday Recipients"}
    }
  },
  {
    "input": "Request budget approval for FY 2025 from the finance committee.",
    "analysis": {
      "instructions": ["seek financial clearance", "initiate annual planning"],
      "actions": ["submit proposal", "review by committee", "track response"],
      "user_info": {"name": "Finance Committee", "designation": "Approving Authority"}
    }
  },
  {
    "input": "Notify employees about the revised dress code starting next month.",
    "analysis": {
      "instructions": ["communicate HR policy", "enforce dress code"],
      "actions": ["draft message", "send email", "post on portal"],
      "user_info": {"name": "All Employees", "designation": "Staff"}
    }
  },
  {
    "input": "Assign an office laptop to new joiner Akshay Dutta.",
    "analysis": {
      "instructions": ["allocate IT equipment", "support onboarding"],
      "actions": ["select available device", "update asset log", "handover to Akshay"],
      "user_info": {"name": "Akshay Dutta", "designation": "New Joiner"}
    }
  },
  {
    "input": "Deactivate project workspace 'VisionX' due to completion.",
    "analysis": {
      "instructions": ["close project resources", "archive workspace"],
      "actions": ["notify members", "lock files", "save final version"],
      "user_info": {"name": "VisionX", "designation": "Project Workspace"}
    }
  },
  {
    "input": "Add Ms. Ritu Jain to the payroll for this month with joining date as 5th.",
    "analysis": {
      "instructions": ["update employee records", "add to payroll system"],
      "actions": ["enter details", "set effective date", "calculate prorated salary"],
      "user_info": {"name": "Ritu Jain", "designation": "New Hire"}
    }
  },
  {
    "input": "Block USB ports on all public terminal computers.",
    "analysis": {
      "instructions": ["enhance data security", "restrict external access"],
      "actions": ["identify public terminals", "disable ports", "document changes"],
      "user_info": {"name": "Public Terminals", "designation": "Workstations"}
    }
  },
  {
    "input": "Schedule an external team-building workshop for the sales division.",
    "analysis": {
      "instructions": ["plan engagement event", "develop team synergy"],
      "actions": ["find facilitator", "book venue", "share schedule"],
      "user_info": {"name": "Sales Division", "designation": "Department"}
    }
  },
  {
    "input": "Prepare and send client onboarding guide to Mr. Sameer Verma.",
    "analysis": {
      "instructions": ["share client documentation", "initiate onboarding"],
      "actions": ["personalize guide", "email document", "log delivery"],
      "user_info": {"name": "Sameer Verma", "designation": "Client"}
    }
  },
  {
    "input": "Publish quarterly CSR report on the company’s website and intranet.",
    "analysis": {
      "instructions": ["share public report", "ensure transparency"],
      "actions": ["review content", "upload to portals", "notify stakeholders"],
      "user_info": {"name": "CSR Report", "designation": "Publication"}
    }
  },
  {
    "input": "Limit Slack channel creation to only team leads.",
    "analysis": {
      "instructions": ["control communication settings", "reduce clutter"],
      "actions": ["update Slack permissions", "inform employees", "monitor compliance"],
      "user_info": {"name": "Team Leads", "designation": "Authorized Users"}
    }
  },
  {
    "input": "Archive last year’s recruitment records to secure cloud storage.",
    "analysis": {
      "instructions": ["organize old records", "ensure backup"],
      "actions": ["zip files", "upload to cloud", "restrict access"],
      "user_info": {"name": "Recruitment Records", "designation": "Archived Data"}
    }
  },
  {
    "input": "Reset passwords for employees returning from extended leave.",
    "analysis": {
      "instructions": ["secure user accounts", "enable reactivation"],
      "actions": ["identify returning staff", "reset passwords", "email credentials"],
      "user_info": {"name": "Returning Employees", "designation": "Staff"}
    }
  },
  {
    "input": "Launch exit survey to collect feedback from departing employees.",
    "analysis": {
      "instructions": ["gather exit feedback", "improve retention strategy"],
      "actions": ["create survey", "share with exit list", "analyze responses"],
      "user_info": {"name": "Departing Employees", "designation": "Ex-Staff"}
    }
  },
  {
    "input": "Schedule medical checkups for field workers this Friday at 10 AM.",
    "analysis": {
      "instructions": ["arrange health services", "ensure employee welfare"],
      "actions": ["book doctor", "notify field workers", "confirm attendance"],
      "user_info": {"name": "Field Workers", "designation": "Employees"}
    }
  }


]

# %%
def transform_entry(entry):
    return {
        "input": entry["input"],
        "output": json.dumps(entry["analysis"])
    }

# %%
from sklearn.model_selection import train_test_split

transformed_data = [transform_entry(entry) for entry in original_data]

train_data, val_data = train_test_split(
    transformed_data,
    test_size=0.2,
    random_state=42
)

# %%
def save_jsonl(data, filename):
    with open(filename, 'w') as f:
        for entry in data:
            f.write(json.dumps(entry) + '\n')

save_jsonl(train_data, 'train.jsonl')
save_jsonl(val_data, 'val.jsonl')

# %%
# !pip install transformers datasets torch sentencepiece
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install --upgrade datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 21.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
pip install bert-score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.8 MB/s eta 0:00:00
# ...

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments
from datasets import load_dataset
import numpy as np

import torch
dataset = load_dataset('json', data_files={
    'train': 'train.jsonl',
    'validation': 'val.jsonl'
})


from transformers import BartForConditionalGeneration, BartTokenizer

tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")


def preprocess(examples):
    inputs = ["input: " + doc for doc in examples["input"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples["output"],
            max_length=256,
            truncation=True,
            padding="max_length"
        )
    labels["input_ids"] = [
        [(token if token != tokenizer.pad_token_id else -100) for token in seq]
        for seq in labels["input_ids"]
    ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_data = dataset.map(preprocess, batched=True)

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    eval_strategy="steps",
    eval_steps=500,
    save_steps=1000,
    fp16=True,
    learning_rate=1e-4,
    logging_steps=200,
    num_train_epochs=10,
    logging_dir="./logs",
    load_best_model_at_end=True,
)
model.gradient_checkpointing_enable()

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],


)

trainer.train()

model.save_pretrained("./fine_tuned_t5")
tokenizer.save_pretrained("./fine_tuned_t5")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# ...

# %%
from transformers import DataCollatorForSeq2Seq
from torch.utils.data import DataLoader
import difflib
from tqdm import tqdm
import torch

# %%
# !pip install evaluate
import evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# Make sure to remove the original raw string columns to prevent DataLoader errors
tokenized_data = dataset.map(preprocess, batched=True, remove_columns=["input", "output"])

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, padding=True)

val_loader = DataLoader(
    tokenized_data["validation"],
    batch_size=2,
    collate_fn=data_collator
)
# Out:
# ...
# Map:   0%|          | 0/60 [00:00<?, ? examples/s]

# %%
import evaluate
meteor = evaluate.load("meteor")
# Out:
# ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# Use the original dataset, not the tokenized one
for example in dataset["validation"]:
    input_text = "input: " + example["input"]
    reference_output = example["output"]

    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, padding="max_length", max_length=512).to(device)

    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_length=256
        )

    decoded_pred = tokenizer.decode(outputs[0], skip_special_tokens=True)
    predictions.append(decoded_pred)
    references.append(reference_output)

# %%
meteor_score = meteor.compute(predictions=predictions, references=references)
print("METEOR Score:", meteor_score["meteor"])
# Out:
# METEOR Score: 0.8478513888744832

# %%
from transformers import pipeline

pipe = pipeline(
    "text2text-generation",
    model="./fine_tuned_t5",
    tokenizer="./fine_tuned_t5",
    device=0 if torch.cuda.is_available() else -1
)

custom_input = "He is Rohit. He is very good guy,increase his salary to 5000"

generated = pipe(
    "input: " + custom_input,
    max_length=128,
    num_beams=1,
    early_stopping=True
)

print("Input:", custom_input)
print("Generated:", generated[0]['generated_text'])
# Out:
# Device set to use cuda:0
# The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Both `max_new_tokens` (=256) and `max_length`(=128) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Input: He is Rohit. He is very good guy,increase his salary to 5000
# Generated: {"instructions": ["raise salary to 5000", "increase employee compensation"], "actions": ["modify prorated salary", "update prorating", "verify salary"], "user_info": {"name": "Rohit", "designation": "Employee"}}
